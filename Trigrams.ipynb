# %% [markdown]
# #Tri-grams (Calculating the probabilities and perplexities based on train and test files)

# %%
# author: Rthvik Raviprakash
# email: rthvik.07@gmail.com
# date: 03/19/2023

# %%
# import the required libraries
from collections import Counter
import numpy as np
import pandas as pd
import re

# %%
file_str = "" # The path of the file that contains that training tokens. In my case it is of sentences form line by line.
a = np.loadtxt(file_str,dtype = "str", delimiter = "\n") # The output shown is an example from the file that I had used.
a
# Out:
# array(['Having a little flexibility on that issue would go a long way to putting together a final package .',
#        'Long before the advent of e-commerce , Wal-Mart \'s founder Sam Walton set out his vision for a successful retail operation : " We let folks know we \'re interested in them and that they \'re vital to us-- \' cause they are , " he said .',
#        'A spokesman said the company has been affected by the credit crunch in the United States .',
#        ..., 'Wisconsin ( 11 ) vs Ohio St. , 4 p.m.',
#        'Of course , they think that a lot of this stuff is genetic .',
#        'By the age of seven , the boy had been seen by doctors more than 325 times and undergone nine operations .'],
#       dtype='<U2467')

# %%
# Get the unigram counts of each word in the vocabulary
cnt = {}
with open(file_str) as file:
  for line in file:
    a = line.split()
    a.append('<s t o p>')
    ar_sub = ['<s t a r t>'] + a
    for value in ar_sub:
      if value not in cnt:
        cnt[value] = 1
      else:
        cnt[value] += 1

# %%
# A dictionary of unknown words
k = 5 # You can change the value of k based on what you want to consider and unknown token to be. (In my case k = 5 which means that any
# word that occurs less than 5 times in the whole document I will give in an "<unk>" token)
word_dict = {word : "<u n k>" for word, occurrences in cnt.items() if occurrences < k}

# %%
# The vocab counts is a dictionary that contains the counts of each unique word in the document (which is basically the vocabulary).
vocab_counts = {}
vocab_counts['<u n k>'] = 0

for k,v in cnt.items():
  if v >= 5:
    vocab_counts[k] = v
  else:
    vocab_counts['<u n k>'] += v

# %%
N = 0
for k,v in vocab_counts.items():
  N += v # N is the total number of words in the document (Note: this is not the unique number of words that are in the document, since that would be V)

p_unk = vocab_counts['<u n k>']/N

# Unigram Model
V = len(vocab_counts) # This is the total number of words in the vocabulary
words_li = []
prob_li = []

word_prob_uni = {}

for k,v in vocab_counts.items():
  words_li.append(k)
  prob_li.append(v/N)
  word_prob_uni[k] = v/N

di = {'Word': words_li, 'Probability' : prob_li}
df = pd.DataFrame(data = di) # This dataframe consists of each word(token) and it's respective probabilities under the unigram model.
df
# Out:
#               Word  Probability
# 0          <u n k>     0.055330
# 1      <s t a r t>     0.036529
# 2           Having     0.000028
# 3                a     0.018674
# 4           little     0.000275
# ...            ...          ...
# 18115      paraded     0.000003
# 18116          CSR     0.000003
# 18117         SiRF     0.000003
# 18118     helpless     0.000003
# 18119     hideouts     0.000003
#
# [18120 rows x 2 columns]

# %%
import string

# Function for tokenizing a sentence
def tokenize(sentence):
  return sentence.split()

# Function for tokenizing a sentence into a bigram.
def token_bi(sentence, unk_dict):
  arr = sentence.split()
  bi_gram = []

  if len(arr) == 0:
    return bi_gram
  
  if len(arr) == 1:
    if arr[0] not in unk_dict:
      return [('<s t a r t>', arr[0]), (arr[0], '<s t o p>')]
    else:
      return [('<s t a r t>', '<u n k>'), ('<u n k>', '<s t o p>')]

  i = 0

  while i < len(arr):
    if i == 0:
      if arr[i] not in unk_dict:
        bi_gram.append(('<s t a r t>', arr[i]))
      else:
        bi_gram.append(('<s t a r t>', '<u n k>'))
      i += 1

    elif i == len(arr) - 1:
      if arr[i] not in unk_dict:
        if arr[i-1] not in unk_dict:
          bi_gram.append((arr[i-1], arr[i]))
          bi_gram.append((arr[i], '<s t o p>'))
        else:
          bi_gram.append(('<u n k>', arr[i]))
          bi_gram.append((arr[i], '<s t o p>'))
      else:
        if arr[i-1] not in unk_dict:
          bi_gram.append((arr[i-1], '<u n k>'))
          bi_gram.append(('<u n k>', '<s t o p>'))
        else:
          bi_gram.append(('<u n k>', '<u n k>'))
          bi_gram.append(('<u n k>', '<s t o p>'))
      i += 1

    else:
      if arr[i] not in unk_dict:
        if arr[i-1] not in unk_dict:
          bi_gram.append((arr[i-1], arr[i]))
        else:
          bi_gram.append(('<u n k>', arr[i]))
      else:
        if arr[i-1] not in unk_dict:
          bi_gram.append((arr[i-1], '<u n k>'))
        else:
          bi_gram.append(('<u n k>', '<u n k>'))
      i += 1
  
  return bi_gram

# %%
# This function takes in a sentence and a dictionary that contains words labeled as unknown and returns the trigrams for that sentence
# For example: If we have a sentence: "This is a unigram model." it would return a list [("<start>", "<start>", "<start>"), ("<start>", "<start>", "This")
# ("<start>", "This", "is"), ("This", "is", "a"), ("is", "a", "unigram"), ("a", "unigram", "model"), ("unigram", "model", "<stop>")]
# If any of the words in that sentence exists in the unknown dictionary, it will return with that word's label as "<unk>"

def token_tri(sentence, unk_dict):
  arr_sub = sentence.split()
  arr_sub.append("<s t o p>")
  arr_tri = ["<s t a r t>", "<s t a r t>"] + arr_sub
  tri_gram = []

  if len(arr_tri) == 3:
    return []
  j = 0

  while j < len(arr_tri) - 2:
    if arr_tri[j] not in unk_dict:
      if arr_tri[j + 1] not in unk_dict:
        if arr_tri[j+2] not in unk_dict:
          tri_gram.append((arr_tri[j], arr_tri[j+1], arr_tri[j+2]))
        else:
          tri_gram.append((arr_tri[j], arr_tri[j+1], '<u n k>'))
      else:
        if arr_tri[j+2] not in unk_dict:
          tri_gram.append((arr_tri[j],'<u n k>' , arr_tri[j+2]))
        else:
          tri_gram.append((arr_tri[j], '<u n k>', '<u n k>'))
      j += 1
    else:
      if arr_tri[j + 1] not in unk_dict:
        if arr_tri[j+2] not in unk_dict:
          tri_gram.append(('<u n k>', arr_tri[j+1], arr_tri[j+2]))
        else:
          tri_gram.append(('<u n k>', arr_tri[j+1], '<u n k>'))
      else:
        if arr_tri[j+2] not in unk_dict:
          tri_gram.append(('<u n k>','<u n k>' , arr_tri[j+2]))
        else:
          tri_gram.append(('<u n k>', '<u n k>', '<u n k>'))
      j += 1

  return tri_gram

# %%
# Get the tri-gram counts for all words in the vocabulary
cnt_tri = {}
cnt_half_tri = 0
with open(file_str) as file:
  for line in file:
    arr = token_tri(line, word_dict)
    for tri in arr:
      if tri not in cnt_tri:
        cnt_tri[tri] = 1
      else:
        cnt_tri[tri] += 1

cnt_tri
# Out:
# {('<s t a r t>', '<s t a r t>', 'Having'): 43,
#  ('<s t a r t>', 'Having', 'a'): 3,
#  ('Having', 'a', 'little'): 1,
#  ('a', 'little', 'flexibility'): 1,
#  ('little', 'flexibility', 'on'): 1,
#  ('flexibility', 'on', 'that'): 1,
#  ('on', 'that', 'issue'): 2,
#  ('that', 'issue', 'would'): 1,
#  ('issue', 'would', 'go'): 1,
#  ('would', 'go', 'a'): 1,
#  ('go', 'a', 'long'): 1,
#  ('a', 'long', 'way'): 14,
#  ('long', 'way', 'to'): 3,
#  ('way', 'to', 'putting'): 1,
#  ('to', 'putting', 'together'): 1,
#  ('putting', 'together', 'a'): 3,
#  ('together', 'a', 'final'): 1,
#  ('a', 'final', 'package'): 1,
#  ('final', 'package', '.'): 1,
#  ('package', '.', '<s t o p>'): 11,
#  ('<s t a r t>', '<s t a r t>', 'Long'): 9,
#  ('<s t a r t>', 'Long', 'before'): 3,
#  ('Long', 'before', 'the'): 1,
#  ('before', 'the', 'advent'): 1,
#  ('the', 'advent', 'of'): 4,
#  ('advent', 'of', 'e-commerce'): 1,
#  ('of', 'e-commerce', ','): 1,
#  ('e-commerce', ',', 'Wal-Mart'): 1,
#  (',', 'Wal-Mart', "'s"): 1,
#  ('Wal-Mart', "'s", 'founder'): 1,
#  ("'s", 'founder', 'Sam'): 1,
#  ('founder', 'Sam', 'Walton'): 1,
#  ('Sam', 'Walton', 'set'): 1,
#  ('Walton', 'set', 'out'): 1,
#  ('set', 'out', 'his'): 1,
#  ('out', 'his', 'vision'): 2,
#  ('his', 'vision', 'for'): 3,
#  ('vision', 'for', 'a'): 2,
#  ('for', 'a', 'successful'): 1,
#  ('a', 'successful', 'retail'): 1,
#  ('successful', 'retail', 'operation'): 1,
#  ('retail', 'operation', ':'): 1,
#  ('operation', ':', '"'): 1,
#  (':', '"', 'We'): 59,
#  ('"', 'We', 'let'): 1,
#  ('We', 'let', 'folks'): 1,
#  ('let', 'folks', 'know'): 1,
#  ('folks', 'know', 'we'): 1,
#  ('know', 'we', "'re"): 2,
#  ('we', "'re", 'interested'): 2,
#  ("'re", 'interested', 'in'): 2,
#  ('interested', 'in', 'them'): 1,
#  ('in', 'them', 'and'): 2,
#  ('them', 'and', 'that'): 1,
#  ('and', 'that', 'they'): 15,
#  ('that', 'they', "'re"): 9,
#  ('they', "'re", 'vital'): 1,
#  ("'re", 'vital', 'to'): 1,
#  ('vital', 'to', '<u n k>'): 1,
#  ('to', '<u n k>', "'"): 4,
#  ('<u n k>', "'", 'cause'): 1,
#  ("'", 'cause', 'they'): 1,
#  ('cause', 'they', 'are'): 1,
#  ('they', 'are', ','): 3,
#  ('are', ',', '"'): 4,
#  (',', '"', 'he'): 774,
#  ('"', 'he', 'said'): 562,
#  ('he', 'said', '.'): 573,
#  ('said', '.', '<s t o p>'): 2303,
#  ('<s t a r t>', '<s t a r t>', 'A'): 1421,
#  ('<s t a r t>', 'A', 'spokesman'): 43,
#  ('A', 'spokesman', 'said'): 7,
#  ('spokesman', 'said', 'the'): 13,
#  ('said', 'the', 'company'): 19,
#  ('the', 'company', 'has'): 12,
#  ('company', 'has', 'been'): 7,
#  ('has', 'been', 'affected'): 3,
#  ('been', 'affected', 'by'): 4,
#  ('affected', 'by', 'the'): 19,
#  ('by', 'the', 'credit'): 3,
#  ('the', 'credit', 'crunch'): 13,
#  ('credit', 'crunch', 'in'): 2,
#  ('crunch', 'in', 'the'): 1,
#  ('in', 'the', 'United'): 140,
#  ('the', 'United', 'States'): 430,
#  ('United', 'States', '.'): 83,
#  ('States', '.', '<s t o p>'): 84,
#  ('<s t a r t>', '<s t a r t>', 'Abu'): 8,
#  ('<s t a r t>', 'Abu', 'Dhabi'): 3,
#  ('Abu', 'Dhabi', 'is'): 2,
#  ('Dhabi', 'is', 'going'): 1,
#  ('is', 'going', 'ahead'): 2,
#  ('going', 'ahead', 'to'): 1,
#  ('ahead', 'to', 'build'): 1,
#  ('to', 'build', 'solar'): 1,
#  ('build', 'solar', 'city'): 1,
#  ('solar', 'city', 'and'): 1,
#  ('city', 'and', 'no'): 1,
#  ('and', 'no', 'pollution'): 1,
#  ('no', 'pollution', 'city'): 1,
#  ('pollution', 'city', '.'): 1,
#  ('city', '.', '<s t o p>'): 47,
#  ('<s t a r t>', '<s t a r t>', 'Her'): 130,
#  ('<s t a r t>', 'Her', 'back'): 1,
#  ('Her', 'back', 'was'): 1,
#  ('back', 'was', 'torn'): 1,
#  ('was', 'torn', 'open'): 1,
#  ('torn', 'open', ','): 1,
#  ('open', ',', 'her'): 1,
#  (',', 'her', 'liver'): 1,
#  ('her', 'liver', 'was'): 1,
#  ('liver', 'was', 'ruptured'): 1,
#  ('was', 'ruptured', ','): 1,
#  ('ruptured', ',', 'one'): 1,
#  (',', 'one', 'of'): 124,
#  ('one', 'of', 'her'): 10,
#  ('of', 'her', 'lungs'): 1,
#  ('her', 'lungs', 'had'): 1,
#  ('lungs', 'had', 'collapsed'): 1,
#  ('had', 'collapsed', 'and'): 2,
#  ('collapsed', 'and', 'the'): 2,
#  ('and', 'the', 'other'): 22,
#  ('the', 'other', 'was'): 2,
#  ('other', 'was', '<u n k>'): 1,
#  ('was', '<u n k>', '.'): 36,
#  ('<u n k>', '.', '<s t o p>'): 5563,
#  ('<s t a r t>', '<s t a r t>', 'Now'): 180,
#  ('<s t a r t>', 'Now', 'it'): 8,
#  ('Now', 'it', 'has'): 1,
#  ('it', 'has', '175'): 1,
#  ('has', '175', 'staging'): 1,
#  ('175', 'staging', 'centers'): 1,
#  ('staging', 'centers', ','): 1,
#  ('centers', ',', 'where'): 2,
#  (',', 'where', 'volunteers'): 1,
#  ('where', 'volunteers', 'are'): 1,
#  ('volunteers', 'are', 'coordinating'): 1,
#  ('are', 'coordinating', 'get-out-the-vote'): 1,
#  ('coordinating', 'get-out-the-vote', 'efforts'): 1,
#  ('get-out-the-vote', 'efforts', ','): 1,
#  ('efforts', ',', 'said'): 2,
#  (',', 'said', 'Obama'): 2,
#  ('said', 'Obama', "'s"): 5,
#  ('Obama', "'s", 'Georgia'): 1,
#  ("'s", 'Georgia', 'spokeswoman'): 1,
#  ('Georgia', 'spokeswoman', ','): 1,
#  ('spokeswoman', ',', 'Caroline'): 1,
#  (',', 'Caroline', '<u n k>'): 1,
#  ('Caroline', '<u n k>', '.'): 2,
#  ('<s t a r t>', '<s t a r t>', 'How'): 106,
#  ('<s t a r t>', 'How', 'about'): 12,
#  ('How', 'about', 'a'): 3,
#  ('about', 'a', '<u n k>'): 13,
#  ('a', '<u n k>', 'or'): 25,
#  ('<u n k>', 'or', 'family'): 1,
#  ('or', 'family', 'friend'): 1,
#  ('family', 'friend', '?'): 1,
#  ('friend', '?', '<s t o p>'): 1,
#  ('<s t a r t>', '<s t a r t>', 'Butler'): 7,
#  ('<s t a r t>', 'Butler', "'s"): 1,
#  ('Butler', "'s", 'the'): 1,
#  ("'s", 'the', 'scorer'): 1,
#  ('the', 'scorer', '.'): 1,
#  ('scorer', '.', '<s t o p>'): 1,
#  ('<s t a r t>', '<s t a r t>', 'In'): 1744,
#  ('<s t a r t>', 'In', 'the'): 334,
#  ('In', 'the', 'meantime'): 15,
#  ('the', 'meantime', ','): 14,
#  ('meantime', ',', 'the'): 1,
#  (',', 'the', '<u n k>'): 509,
#  ('the', '<u n k>', 'Bell'): 1,
#  ('<u n k>', 'Bell', 'gets'): 1,
#  ('Bell', 'gets', 'to'): 1,
#  ('gets', 'to', 'showcase'): 1,
#  ('to', 'showcase', 'her'): 1,
#  ('showcase', 'her', 'musical'): 1,
#  ('her', 'musical', '<u n k>'): 1,
#  ('musical', '<u n k>', 'during'): 1,
#  ('<u n k>', 'during', 'the'): 31,
#  ('during', 'the', 'end'): 1,
#  ('the', 'end', 'credits'): 1,
#  ('end', 'credits', 'of'): 1,
#  ('credits', 'of', '"'): 2,
#  ('of', '"', 'When'): 1,
#  ('"', 'When', 'in'): 1,
#  ('When', 'in', 'Rome'): 1,
#  ('in', 'Rome', '"'): 1,
#  ('Rome', '"', 'when'): 1,
#  ('"', 'when', 'the'): 3,
#  ('when', 'the', 'cast'): 1,
#  ('the', 'cast', 'breaks'): 1,
#  ('cast', 'breaks', 'in'): 1,
#  ('breaks', 'in', 'to'): 1,
#  ('in', 'to', 'a'): 3,
#  ('to', 'a', 'musical'): 2,
#  ('a', 'musical', 'dance'): 1,
#  ('musical', 'dance', 'number'): 1,
#  ('dance', 'number', '.'): 1,
#  ('number', '.', '<s t o p>'): 7,
#  ('<s t a r t>', '<s t a r t>', 'McCain'): 58,
#  ('<s t a r t>', 'McCain', 'said'): 2,
#  ('McCain', 'said', 'he'): 2,
#  ('said', 'he', 'must'): 1,
#  ('he', 'must', 'convince'): 1,
#  ('must', 'convince', 'Americans'): 1,
#  ('convince', 'Americans', 'that'): 2,
#  ('Americans', 'that', '"'): 1,
#  ('that', '"', 'protectionism'): 1,
#  ('"', 'protectionism', 'and'): 1,
#  ('protectionism', 'and', '<u n k>'): 1,
#  ('and', '<u n k>', '"'): 24,
#  ('<u n k>', '"', 'could'): 1,
#  ('"', 'could', 'be'): 5,
#  ('could', 'be', 'harmful'): 1,
#  ('be', 'harmful', '.'): 1,
#  ('harmful', '.', '<s t o p>'): 2,
#  ('<s t a r t>', '<s t a r t>', 'He'): 1802,
#  ('<s t a r t>', 'He', 'knew'): 5,
#  ('He', 'knew', 'that'): 1,
#  ('knew', 'that', 'this'): 2,
#  ('that', 'this', '<u n k>'): 5,
#  ('this', '<u n k>', 'process'): 1,
#  ('<u n k>', 'process', 'is'): 1,
#  ('process', 'is', 'simply'): 1,
#  ('is', 'simply', 'what'): 1,
#  ('simply', 'what', 'the'): 1,
#  ('what', 'the', 'soul'): 1,
#  ('the', 'soul', '--'): 1,
#  ('soul', '--', 'or'): 1,
#  ('--', 'or', 'true'): 1,
#  ('or', 'true', 'self'): 1,
#  ('true', 'self', ','): 1,
#  ('self', ',', 'if'): 1,
#  (',', 'if', 'you'): 37,
#  ('if', 'you', 'prefer'): 1,
#  ('you', 'prefer', '--'): 1,
#  ('prefer', '--', 'does'): 1,
#  ('--', 'does', 'when'): 1,
#  ('does', 'when', 'we'): 1,
#  ('when', 'we', 'stop'): 2,
#  ('we', 'stop', '<u n k>'): 2,
#  ('stop', '<u n k>', '.'): 1,
#  ('<s t a r t>', '<s t a r t>', '15'): 14,
#  ('<s t a r t>', '15', 'at'): 2,
#  ('15', 'at', 'Carolina'): 1,
#  ('at', 'Carolina', 'Panthers'): 1,
#  ('Carolina', 'Panthers', 'FOX'): 1,
#  ('Panthers', 'FOX', '1'): 1,
#  ('FOX', '1', 'p.m.'): 1,
#  ('1', 'p.m.', '<s t o p>'): 3,
#  ('<s t a r t>', '<s t a r t>', 'Marc'): 5,
#  ('<s t a r t>', 'Marc', 'D.'): 1,
#  ('Marc', 'D.', '<u n k>'): 1,
#  ('D.', '<u n k>', ','): 8,
#  ('<u n k>', ',', 'the'): 782,
#  (',', 'the', 'lawyer'): 3,
#  ('the', 'lawyer', 'who'): 1,
#  ('lawyer', 'who', 'represents'): 1,
#  ('who', 'represents', 'David'): 1,
#  ('represents', 'David', 'M.'): 1,
#  ('David', 'M.', '<u n k>'): 2,
#  ('M.', '<u n k>', ','): 5,
#  (',', 'the', 'licensed'): 1,
#  ('the', 'licensed', 'massage'): 1,
#  ('licensed', 'massage', 'therapist'): 1,
#  ('massage', 'therapist', 'who'): 1,
#  ('therapist', 'who', 'is'): 1,
#  ('who', 'is', '<u n k>'): 6,
#  ('is', '<u n k>', "'s"): 9,
#  ('<u n k>', "'s", 'former'): 6,
#  ("'s", 'former', 'vice'): 1,
#  ('former', 'vice', 'president'): 2,
#  ('vice', 'president', ','): 2,
#  ('president', ',', 'said'): 8,
#  (',', 'said', 'he'): 77,
#  ('said', 'he', 'had'): 47,
#  ('he', 'had', 'sent'): 2,
#  ('had', 'sent', 'a'): 4,
#  ('sent', 'a', 'letter'): 8,
#  ('a', 'letter', 'to'): 22,
#  ('letter', 'to', 'Congress'): 1,
#  ('to', 'Congress', 'saying'): 1,
#  ('Congress', 'saying', 'Mr.'): 1,
#  ('saying', 'Mr.', '<u n k>'): 1,
#  ('Mr.', '<u n k>', 'would'): 1,
#  ('<u n k>', 'would', 'speak'): 1,
#  ('would', 'speak', 'publicly'): 1,
#  ('speak', 'publicly', 'only'): 1,
#  ('publicly', 'only', 'if'): 1,
#  ('only', 'if', 'he'): 3,
#  ('if', 'he', 'was'): 15,
#  ('he', 'was', 'granted'): 1,
#  ('was', 'granted', 'immunity'): 2,
#  ('granted', 'immunity', 'from'): 2,
#  ('immunity', 'from', 'prosecution'): 4,
#  ('from', 'prosecution', '.'): 3,
#  ('prosecution', '.', '<s t o p>'): 8,
#  ('In', 'the', '<u n k>'): 21,
#  ('the', '<u n k>', 'of'): 526,
#  ('<u n k>', 'of', 'circus'): 1,
#  ('of', 'circus', 'and'): 1,
#  ('circus', 'and', 'variety'): 1,
#  ('and', 'variety', 'history'): 1,
#  ('variety', 'history', ','): 1,
#  ('history', ',', 'no'): 1,
#  (',', 'no', 'family'): 1,
#  ('no', 'family', 'better'): 1,
#  ('family', 'better', 'deserved'): 1,
#  ('better', 'deserved', 'the'): 1,
#  ('deserved', 'the', 'description'): 1,
#  ('the', 'description', 'of'): 2,
#  ('description', 'of', '"'): 1,
#  ('of', '"', 'the'): 5,
#  ('"', 'the', 'royal'): 1,
#  ('the', 'royal', 'family'): 4,
#  ('royal', 'family', 'of'): 2,
#  ('family', 'of', '<u n k>'): 4,
#  ('of', '<u n k>', '"'): 18,
#  ('<u n k>', '"', 'than'): 3,
#  ('"', 'than', 'did'): 2,
#  ('than', 'did', 'the'): 2,
#  ('did', 'the', '<u n k>'): 2,
#  ('the', '<u n k>', '.'): 338,
#  ('<s t a r t>', '<s t a r t>', 'One'): 279,
#  ('<s t a r t>', 'One', 'of'): 102,
#  ('One', 'of', 'the'): 79,
#  ('of', 'the', 'defendants'): 4,
#  ('the', 'defendants', 'was'): 1,
#  ('defendants', 'was', 'found'): 1,
#  ('was', 'found', 'not'): 2,
#  ('found', 'not', 'guilty'): 2,
#  ('not', 'guilty', 'and'): 1,
#  ('guilty', 'and', 'the'): 1,
#  ('and', 'the', 'jury'): 1,
#  ('the', 'jury', 'was'): 3,
#  ('jury', 'was', 'unable'): 1,
#  ('was', 'unable', 'to'): 19,
#  ('unable', 'to', 'reach'): 5,
#  ('to', 'reach', 'a'): 15,
#  ('reach', 'a', 'verdict'): 1,
#  ('a', 'verdict', 'for'): 1,
#  ('verdict', 'for', 'four'): 1,
#  ('for', 'four', 'other'): 1,
#  ('four', 'other', 'men'): 1,
#  ('other', 'men', 'on'): 1,
#  ('men', 'on', 'trial'): 1,
#  ('on', 'trial', '.'): 2,
#  ('trial', '.', '<s t o p>'): 32,
#  ('<s t a r t>', '<s t a r t>', 'Nursing'): 1,
#  ('<s t a r t>', 'Nursing', 'Homes'): 1,
#  ('Nursing', 'Homes', ':'): 1,
#  ('Homes', ':', '<u n k>'): 1,
#  (':', '<u n k>', "'s"): 8,
#  ('<u n k>', "'s", '2009'): 2,
#  ("'s", '2009', 'Cost'): 1,
#  ('2009', 'Cost', 'of'): 1,
#  ('Cost', 'of', 'Care'): 1,
#  ('of', 'Care', 'Survey'): 1,
#  ('Care', 'Survey', 'analyzed'): 1,
#  ('Survey', 'analyzed', 'long'): 1,
#  ('analyzed', 'long', 'term'): 1,
#  ('long', 'term', 'care'): 2,
#  ('term', 'care', 'costs'): 1,
#  ('care', 'costs', 'in'): 1,
#  ('costs', 'in', 'two'): 1,
#  ('in', 'two', 'regions'): 1,
#  ('two', 'regions', 'in'): 1,
#  ('regions', 'in', 'Hawaii'): 1,
#  ('in', 'Hawaii', ':'): 1,
#  ('Hawaii', ':', '<u n k>'): 1,
#  (':', '<u n k>', 'and'): 6,
#  ('<u n k>', 'and', 'the'): 182,
#  ('and', 'the', 'rest'): 13,
#  ('the', 'rest', 'of'): 105,
#  ('rest', 'of', 'the'): 76,
#  ('of', 'the', 'state'): 48,
#  ('the', 'state', '.'): 23,
#  ('state', '.', '<s t o p>'): 49,
#  ('<s t a r t>', '<s t a r t>', 'Players'): 8,
#  ('<s t a r t>', 'Players', 'can'): 1,
#  ('Players', 'can', 'take'): 1,
#  ('can', 'take', 'their'): 1,
#  ('take', 'their', 'performances'): 1,
#  ('their', 'performances', 'to'): 1,
#  ('performances', 'to', 'the'): 1,
#  ('to', 'the', 'next'): 11,
#  ('the', 'next', 'level'): 2,
#  ('next', 'level', 'by'): 1,
#  ('level', 'by', 'turning'): 1,
#  ('by', 'turning', 'their'): 1,
#  ('turning', 'their', 'best'): 1,
#  ('their', 'best', '30'): 1,
#  ('best', '30', 'second'): 1,
#  ('30', 'second', 'clips'): 1,
#  ('second', 'clips', 'into'): 1,
#  ('clips', 'into', 'their'): 1,
#  ('into', 'their', 'own'): 5,
#  ('their', 'own', 'mini'): 1,
#  ('own', 'mini', 'music'): 1,
#  ('mini', 'music', 'videos'): 1,
#  ('music', 'videos', 'using'): 1,
#  ('videos', 'using', 'a'): 1,
#  ('using', 'a', 'selection'): 1,
#  ('a', 'selection', 'of'): 7,
#  ('selection', 'of', 'special'): 1,
#  ('of', 'special', 'editing'): 1,
#  ('special', 'editing', 'effects'): 1,
#  ('editing', 'effects', '.'): 1,
#  ('effects', '.', '<s t o p>'): 6,
#  ('<s t a r t>', '<s t a r t>', '<u n k>'): 6782,
#  ('<s t a r t>', '<u n k>', 'came'): 3,
#  ('<u n k>', 'came', 'in'): 5,
#  ('came', 'in', 'fifth'): 1,
#  ('in', 'fifth', '.'): 2,
#  ('fifth', '.', '<s t o p>'): 5,
#  ('<s t a r t>', '<s t a r t>', "'"): 25,
#  ('<s t a r t>', "'", 'Coming'): 1,
#  ("'", 'Coming', 'Home'): 1,
#  ('Coming', 'Home', "'"): 1,
#  ('Home', "'", 'was'): 1,
#  ("'", 'was', 'released'): 2,
#  ('was', 'released', 'in'): 4,
#  ('released', 'in', 'October'): 1,
#  ('in', 'October', 'last'): 5,
#  ('October', 'last', 'year'): 5,
#  ('last', 'year', '.'): 125,
#  ('year', '.', '<s t o p>'): 496,
#  ('<s t a r t>', '<s t a r t>', 'Bush'): 32,
#  ('<s t a r t>', 'Bush', 'is'): 4,
#  ('Bush', 'is', 'remembered'): 1,
#  ('is', 'remembered', 'by'): 1,
#  ('remembered', 'by', 'many'): 1,
#  ('by', 'many', 'Haitians'): 1,
#  ('many', 'Haitians', '--'): 1,
#  ('Haitians', '--', 'especially'): 1,
#  ('--', 'especially', 'the'): 2,
#  ('especially', 'the', 'thousands'): 1,
#  ('the', 'thousands', 'in'): 1,
#  ('thousands', 'in', 'Port-au-Prince'): 1,
#  ('in', 'Port-au-Prince', "'s"): 1,
#  ('Port-au-Prince', "'s", '<u n k>'): 1,
#  ("'s", '<u n k>', 'slums'): 1,
#  ('<u n k>', 'slums', '--'): 1,
#  ('slums', '--', 'as'): 1,
#  ('--', 'as', 'the'): 3,
#  ('as', 'the', 'U.S.'): 5,
#  ('the', 'U.S.', 'leader'): 1,
#  ('U.S.', 'leader', 'whose'): 1,
#  ('leader', 'whose', 'administration'): 1,
#  ('whose', 'administration', '<u n k>'): 1,
#  ('administration', '<u n k>', 'the'): 1,
#  ('<u n k>', 'the', 'plane'): 2,
#  ('the', 'plane', 'that'): 1,
#  ('plane', 'that', 'flew'): 2,
#  ('that', 'flew', '<u n k>'): 1,
#  ('flew', '<u n k>', 'back'): 1,
#  ('<u n k>', 'back', 'into'): 3,
#  ('back', 'into', 'exile'): 1,
#  ('into', 'exile', 'during'): 1,
#  ('exile', 'during', 'a'): 1,
#  ('during', 'a', '2004'): 1,
#  ('a', '2004', 'rebellion'): 1,
#  ('2004', 'rebellion', '.'): 1,
#  ('rebellion', '.', '<s t o p>'): 3,
#  ('<s t a r t>', '<s t a r t>', 'Last'): 178,
#  ('<s t a r t>', 'Last', 'week'): 47,
#  ('Last', 'week', 'top'): 1,
#  ('week', 'top', 'US'): 1,
#  ('top', 'US', 'military'): 4,
#  ('US', 'military', 'officer'): 2,
#  ('military', 'officer', 'Admiral'): 1,
#  ('officer', 'Admiral', 'Mike'): 1,
#  ('Admiral', 'Mike', 'Mullen'): 2,
#  ('Mike', 'Mullen', 'said'): 1,
#  ('Mullen', 'said', 'this'): 1,
#  ('said', 'this', 'increased'): 1,
#  ('this', 'increased', 'the'): 1,
#  ('increased', 'the', 'flow'): 1,
#  ('the', 'flow', 'of'): 16,
#  ('flow', 'of', 'militants'): 2,
#  ('of', 'militants', 'into'): 1,
#  ('militants', 'into', 'Afghanistan'): 1,
#  ('into', 'Afghanistan', 'to'): 2,
#  ('Afghanistan', 'to', 'combat'): 1,
#  ('to', 'combat', 'Nato'): 1,
#  ('combat', 'Nato', 'troops'): 1,
#  ('Nato', 'troops', '.'): 1,
#  ('troops', '.', '<s t o p>'): 20,
#  ('<s t a r t>', '<u n k>', 'Inc'): 3,
#  ('<u n k>', 'Inc', '.'): 27,
#  ('Inc', '.', ','): 64,
#  ('.', ',', 'the'): 24,
#  (',', 'the', 'petroleum'): 1,
#  ('the', 'petroleum', 'refining'): 1,
#  ('petroleum', 'refining', 'company'): 1,
#  ('refining', 'company', ','): 1,
#  ('company', ',', 'said'): 5,
#  (',', 'said', 'on'): 10,
#  ('said', 'on', 'Wednesday'): 26,
#  ('on', 'Wednesday', 'that'): 14,
#  ('Wednesday', 'that', 'it'): 6,
#  ('that', 'it', 'had'): 35,
#  ('it', 'had', 'hired'): 1,
#  ('had', 'hired', 'Lynn'): 1,
#  ('hired', 'Lynn', '<u n k>'): 1,
#  ('Lynn', '<u n k>', '<u n k>'): 1,
#  ('<u n k>', '<u n k>', 'as'): 30,
#  ('<u n k>', 'as', 'its'): 5,
#  ('as', 'its', 'chief'): 1,
#  ('its', 'chief', 'executive'): 4,
#  ('chief', 'executive', ','): 35,
#  ('executive', ',', 'succeeding'): 1,
#  (',', 'succeeding', 'John'): 1,
#  ('succeeding', 'John', '<u n k>'): 1,
#  ('John', '<u n k>', ','): 41,
#  ('<u n k>', ',', 'who'): 560,
#  (',', 'who', 'is'): 148,
#  ('who', 'is', 'retiring'): 1,
#  ('is', 'retiring', 'in'): 1,
#  ('retiring', 'in', 'August'): 1,
#  ('in', 'August', '.'): 16,
#  ('August', '.', '<s t o p>'): 36,
#  ('<s t a r t>', '<s t a r t>', 'Under'): 96,
#  ('<s t a r t>', 'Under', 'the'): 58,
#  ('Under', 'the', 'terms'): 5,
#  ('the', 'terms', 'of'): 21,
#  ('terms', 'of', 'the'): 12,
#  ('of', 'the', 'agreement'): 8,
#  ('the', 'agreement', ','): 4,
#  ('agreement', ',', '<u n k>'): 1,
#  (',', '<u n k>', 'was'): 43,
#  ('<u n k>', 'was', 'paid'): 4,
#  ('was', 'paid', 'an'): 1,
#  ('paid', 'an', 'annual'): 1,
#  ('an', 'annual', 'consulting'): 1,
#  ('annual', 'consulting', 'fee'): 1,
#  ('consulting', 'fee', 'of'): 1,
#  ('fee', 'of', '$'): 2,
#  ('of', '$', '50,000'): 3,
#  ('$', '50,000', 'and'): 1,
#  ('50,000', 'and', 'entitled'): 1,
#  ('and', 'entitled', 'to'): 1,
#  ('entitled', 'to', '120'): 1,
#  ('to', '120', 'hours'): 1,
#  ('120', 'hours', 'per'): 1,
#  ('hours', 'per', 'year'): 2,
#  ('per', 'year', 'of'): 1,
#  ('year', 'of', 'flying'): 1,
#  ('of', 'flying', 'time'): 1,
#  ('flying', 'time', 'on'): 1,
#  ('time', 'on', 'a'): 2,
#  ('on', 'a', 'corporate'): 1,
#  ('a', 'corporate', 'jet'): 1,
#  ('corporate', 'jet', 'provided'): 1,
#  ('jet', 'provided', 'by'): 1,
#  ('provided', 'by', 'BofA'): 1,
#  ('by', 'BofA', '.'): 1,
#  ('BofA', '.', '<s t o p>'): 1,
#  ('<s t a r t>', '<s t a r t>', 'The'): 8913,
#  ('<s t a r t>', 'The', '<u n k>'): 860,
#  ('The', '<u n k>', 'surrounding'): 1,
#  ('<u n k>', 'surrounding', 'the'): 3,
#  ('surrounding', 'the', '<u n k>'): 1,
#  ('the', '<u n k>', 'even'): 1,
#  ('<u n k>', 'even', 'forced'): 1,
#  ('even', 'forced', '<u n k>'): 1,
#  ('forced', '<u n k>', 'to'): 2,
#  ('<u n k>', 'to', 'ensure'): 1,
#  ('to', 'ensure', 'the'): 17,
#  ('ensure', 'the', 'Olympics'): 1,
#  ('the', 'Olympics', 'would'): 2,
#  ('Olympics', 'would', 'not'): 1,
#  ('would', 'not', 'be'): 54,
#  ('not', 'be', 'a'): 12,
#  ('be', 'a', 'battle'): 1,
#  ('a', 'battle', 'of'): 2,
#  ('battle', 'of', '<u n k>'): 3,
#  ('of', '<u n k>', 'against'): 4,
#  ('<u n k>', 'against', '<u n k>'): 6,
#  ('against', '<u n k>', '-'): 2,
#  ('<u n k>', '-', 'particularly'): 1,
#  ('-', 'particularly', 'when'): 1,
#  ('particularly', 'when', 'the'): 2,
#  ('when', 'the', '<u n k>'): 34,
#  ('the', '<u n k>', 'has'): 29,
#  ('<u n k>', 'has', 'a'): 25,
#  ('has', 'a', 'price'): 1,
#  ('a', 'price', 'tag'): 1,
#  ('price', 'tag', 'of'): 1,
#  ('tag', 'of', '$'): 1,
#  ('of', '$', '550'): 1,
#  ('$', '550', '('): 1,
#  ('550', '(', '£'): 1,
#  ('(', '£', '<u n k>'): 44,
#  ('£', '<u n k>', ')'): 41,
#  ('<u n k>', ')', '-'): 6,
#  (')', '-', 'by'): 1,
#  ('-', 'by', 'allowing'): 1,
#  ('by', 'allowing', 'all'): 1,
#  ('allowing', 'all', 'of'): 1,
#  ('all', 'of', 'the'): 39,
#  ('of', 'the', 'major'): 9,
#  ('the', 'major', 'manufacturers'): 1,
#  ('major', 'manufacturers', 'to'): 1,
#  ('manufacturers', 'to', 'hand'): 1,
#  ('to', 'hand', 'out'): 2,
#  ('hand', 'out', 'suits'): 1,
#  ('out', 'suits', 'to'): 1,
#  ('suits', 'to', 'national'): 1,
#  ('to', 'national', 'teams'): 1,
#  ('national', 'teams', '.'): 1,
#  ('teams', '.', '<s t o p>'): 15,
#  ('<s t a r t>', '<s t a r t>', 'Barr'): 3,
#  ('<s t a r t>', 'Barr', 'Pharmaceuticals'): 1,
#  ('Barr', 'Pharmaceuticals', 'said'): 1,
#  ('Pharmaceuticals', 'said', 'Friday'): 1,
#  ('said', 'Friday', 'that'): 6,
#  ('Friday', 'that', 'it'): 4,
#  ('that', 'it', 'planned'): 5,
#  ('it', 'planned', 'to'): 8,
#  ('planned', 'to', 'introduce'): 2,
#  ('to', 'introduce', 'its'): 1,
#  ('introduce', 'its', 'generic'): 1,
#  ('its', 'generic', 'version'): 2,
#  ('generic', 'version', 'of'): 2,
#  ('version', 'of', 'the'): 27,
#  ('of', 'the', 'basic'): 1,
#  ('the', 'basic', '<u n k>'): 3,
#  ('basic', '<u n k>', 'form'): 1,
#  ('<u n k>', 'form', 'of'): 5,
#  ('form', 'of', '<u n k>'): 14,
#  ('of', '<u n k>', 'on'): 26,
#  ('<u n k>', 'on', 'Feb'): 1,
#  ('on', 'Feb', '.'): 13,
#  ('Feb', '.', '<s t o p>'): 41,
#  ('<s t a r t>', '<s t a r t>', 'Qatar'): 3,
#  ('<s t a r t>', 'Qatar', "'s"): 2,
#  ('Qatar', "'s", 'economy'): 1,
#  ("'s", 'economy', ','): 3,
#  ('economy', ',', 'which'): 8,
#  (',', 'which', 'has'): 151,
#  ('which', 'has', 'bucked'): 1,
#  ('has', 'bucked', 'the'): 2,
#  ('bucked', 'the', 'regional'): 1,
#  ('the', 'regional', 'recession'): 1,
#  ('regional', 'recession', ','): 1,
#  ('recession', ',', 'should'): 1,
#  (',', 'should', 'grow'): 1,
#  ('should', 'grow', 'by'): 1,
#  ('grow', 'by', 'about'): 1,
#  ('by', 'about', '9'): 1,
#  ('about', '9', 'per'): 1,
#  ('9', 'per', 'cent'): 2,
#  ('per', 'cent', 'this'): 3,
#  ('cent', 'this', 'year'): 3,
#  ('this', 'year', 'and'): 20,
#  ('year', 'and', 'revenues'): 1,
#  ('and', 'revenues', 'will'): 1,
#  ('revenues', 'will', 'jump'): 1,
#  ('will', 'jump', 'by'): 1,
#  ('jump', 'by', 'the'): 1,
#  ('by', 'the', 'end'): 53,
#  ('the', 'end', 'of'): 303,
#  ('end', 'of', 'next'): 8,
#  ('of', 'next', 'year'): 16,
#  ('next', 'year', 'as'): 3,
#  ('year', 'as', 'gas'): 1,
#  ('as', 'gas', 'exports'): 1,
#  ('gas', 'exports', 'almost'): 1,
#  ('exports', 'almost', 'double'): 1,
#  ('almost', 'double', '.'): 1,
#  ('double', '.', '<s t o p>'): 9,
#  ('<s t a r t>', '<s t a r t>', 'Although'): 140,
#  ('<s t a r t>', 'Although', 'not'): 4,
#  ('Although', 'not', 'yet'): 1,
#  ('not', 'yet', 'a'): 1,
#  ('yet', 'a', 'household'): 1,
#  ('a', 'household', 'name'): 2,
#  ('household', 'name', ','): 2,
#  ('name', ',', 'Kyle'): 1,
#  (',', 'Kyle', '<u n k>'): 1,
#  ('Kyle', '<u n k>', 'of'): 1,
#  ('<u n k>', 'of', '<u n k>'): 288,
#  ('of', '<u n k>', 'and'): 201,
#  ('<u n k>', 'and', 'Associates'): 1,
#  ('and', 'Associates', 'is'): 1,
#  ('Associates', 'is', 'at'): 1,
#  ('is', 'at', 'the'): 12,
#  ('at', 'the', 'cutting'): 2,
#  ('the', 'cutting', 'edge'): 3,
#  ('cutting', 'edge', 'of'): 2,
#  ('edge', 'of', 'the'): 10,
#  ('of', 'the', 'rapidly'): 2,
#  ('the', 'rapidly', 'growing'): 2,
#  ('rapidly', 'growing', 'online'): 1,
#  ('growing', 'online', 'business'): 1,
#  ('online', 'business', 'arena'): 1,
#  ('business', 'arena', ';'): 1,
#  ('arena', ';', 'and'): 1,
#  (';', 'and', 'this'): 1,
#  ('and', 'this', 'at'): 1,
#  ('this', 'at', 'the'): 1,
#  ('at', 'the', 'announcement'): 1,
#  ('the', 'announcement', 'of'): 4,
#  ('announcement', 'of', 'his'): 1,
#  ('of', 'his', 'new'): 1,
#  ('his', 'new', 'joint'): 1,
#  ('new', 'joint', 'venture'): 1,
#  ('joint', 'venture', 'with'): 8,
#  ('venture', 'with', '<u n k>'): 2,
#  ('with', '<u n k>', 'Express'): 1,
#  ('<u n k>', 'Express', '.'): 2,
#  ('Express', '.', '<s t o p>'): 3,
#  ('<s t a r t>', '<s t a r t>', 'Officials'): 62,
#  ('<s t a r t>', 'Officials', 'fear'): 2,
#  ('Officials', 'fear', 'that'): 2,
#  ('fear', 'that', 'bulls'): 1,
#  ('that', 'bulls', 'are'): 1,
#  ('bulls', 'are', 'being'): 1,
#  ('are', 'being', '<u n k>'): 9,
#  ('being', '<u n k>', 'with'): 2,
#  ('<u n k>', 'with', '<u n k>'): 81,
#  ('with', '<u n k>', 'to'): 13,
#  ('<u n k>', 'to', 'make'): 15,
#  ('to', 'make', 'them'): 5,
#  ('make', 'them', 'less'): 1,
#  ('them', 'less', 'aggressive'): 1,
#  ('less', 'aggressive', ','): 1,
#  ('aggressive', ',', 'giving'): 1,
#  (',', 'giving', 'the'): 6,
#  ('giving', 'the', '<u n k>'): 2,
#  ('the', '<u n k>', 'a'): 8,
#  ('<u n k>', 'a', 'crucial'): 1,
#  ('a', 'crucial', 'edge'): 1,
#  ('crucial', 'edge', 'in'): 1,
#  ('edge', 'in', 'the'): 2,
#  ('in', 'the', 'contest'): 2,
#  ('the', 'contest', '.'): 2,
#  ('contest', '.', '<s t o p>'): 11,
#  ('<s t a r t>', 'The', 'Interior'): 2,
#  ('The', 'Interior', 'Department'): 1,
#  ('Interior', 'Department', "'s"): 2,
#  ('Department', "'s", 'Minerals'): 1,
#  ("'s", 'Minerals', 'Management'): 1,
#  ('Minerals', 'Management', 'Service'): 2,
#  ('Management', 'Service', 'said'): 1,
#  ('Service', 'said', 'yesterday'): 1,
#  ('said', 'yesterday', 'that'): 9,
#  ('yesterday', 'that', 'only'): 1,
#  ('that', 'only', '61'): 1,
#  ('only', '61', 'percent'): 1,
#  ('61', 'percent', 'of'): 3,
#  ('percent', 'of', 'oil'): 2,
#  ('of', 'oil', 'production'): 4,
#  ('oil', 'production', 'in'): 2,
#  ('production', 'in', 'the'): 4,
#  ('in', 'the', 'Gulf'): 15,
#  ('the', 'Gulf', 'of'): 14,
#  ('Gulf', 'of', 'Mexico'): 9,
#  ('of', 'Mexico', 'has'): 1,
#  ('Mexico', 'has', 'been'): 2,
#  ('has', 'been', 'restored'): 2,
#  ('been', 'restored', 'as'): 1,
#  ('restored', 'as', 'companies'): 1,
#  ('as', 'companies', 'struggle'): 2,
#  ('companies', 'struggle', 'with'): 1,
#  ('struggle', 'with', 'repairs'): 1,
#  ('with', 'repairs', 'to'): 1,
#  ('repairs', 'to', 'platforms'): 1,
#  ('to', 'platforms', '.'): 1,
#  ('platforms', '.', '<s t o p>'): 4,
#  ('<s t a r t>', '<s t a r t>', 'And'): 778,
#  ('<s t a r t>', 'And', 'finally'): 8,
#  ('And', 'finally', 'for'): 1,
#  ('finally', 'for', 'MTV'): 1,
#  ('for', 'MTV', ','): 1,
#  ('MTV', ',', 'they'): 1,
#  (',', 'they', 'have'): 32,
#  ('they', 'have', 'produced'): 1,
#  ('have', 'produced', 'the'): 1,
#  ('produced', 'the', 'most'): 2,
#  ('the', 'most', 'talked'): 2,
#  ('most', 'talked', 'about'): 3,
#  ('talked', 'about', '<u n k>'): 2,
#  ('about', '<u n k>', 'since'): 1,
#  ('<u n k>', 'since', 'that'): 1,
#  ('since', 'that', 'Jackson'): 1,
#  ('that', 'Jackson', 'and'): 1,
#  ('Jackson', 'and', 'Presley'): 1,
#  ('and', 'Presley', 'kiss'): 1,
#  ('Presley', 'kiss', '.'): 1,
#  ('kiss', '.', '<s t o p>'): 1,
#  ('The', '<u n k>', 'Czech'): 1,
#  ('<u n k>', 'Czech', 'leader'): 1,
#  ('Czech', 'leader', ','): 1,
#  ('leader', ',', 'the'): 3,
#  (',', 'the', 'last'): 18,
#  ('the', 'last', 'hurdle'): 1,
#  ('last', 'hurdle', 'for'): 1,
#  ('hurdle', 'for', 'a'): 2,
#  ('for', 'a', 'treaty'): 1,
#  ('a', 'treaty', 'that'): 4,
#  ('treaty', 'that', 'has'): 1,
#  ('that', 'has', 'taken'): 1,
#  ('has', 'taken', 'eight'): 1,
#  ('taken', 'eight', 'years'): 1,
#  ('eight', 'years', 'to'): 2,
#  ('years', 'to', 'stumble'): 1,
#  ('to', 'stumble', 'to'): 1,
#  ('stumble', 'to', 'the'): 1,
#  ('to', 'the', 'finishing'): 1,
#  ('the', 'finishing', 'tape'): 1,
#  ('finishing', 'tape', ','): 1,
#  ('tape', ',', 'insists'): 1,
#  (',', 'insists', 'that'): 1,
#  ('insists', 'that', 'the'): 2,
#  ('that', 'the', 'EU'): 7,
#  ('the', 'EU', 'must'): 1,
#  ('EU', 'must', 'first'): 1,
#  ('must', 'first', 'grant'): 1,
#  ('first', 'grant', 'the'): 1,
#  ('grant', 'the', 'Czech'): 1,
#  ('the', 'Czech', 'Republic'): 22,
#  ('Czech', 'Republic', 'an'): 1,
#  ('Republic', 'an', '<u n k>'): 1,
#  ('an', '<u n k>', '<u n k>'): 70,
#  ('<u n k>', '<u n k>', '.'): 657,
#  ('<s t a r t>', 'He', 'said'): 257,
#  ('He', 'said', ':'): 33,
#  ('said', ':', '"'): 302,
#  (':', '"', 'I'): 61,
#  ('"', 'I', "'m"): 70,
#  ('I', "'m", 'extremely'): 3,
#  ("'m", 'extremely', 'sorry'): 1,
#  ('extremely', 'sorry', 'to'): 1,
#  ('sorry', 'to', 'hear'): 1,
#  ('to', 'hear', 'that'): 3,
#  ('hear', 'that', 'a'): 1,
#  ('that', 'a', 'young'): 1,
#  ('a', 'young', 'lad'): 1,
#  ('young', 'lad', 'has'): 1,
#  ('lad', 'has', 'passed'): 1,
#  ('has', 'passed', 'away'): 1,
#  ('passed', 'away', 'in'): 1,
#  ('away', 'in', 'such'): 1,
#  ('in', 'such', 'a'): 14,
#  ('such', 'a', 'tragic'): 2,
#  ('a', 'tragic', 'way'): 1,
#  ('tragic', 'way', '.'): 1,
#  ('way', '.', '<s t o p>'): 76,
#  ('<s t a r t>', '<s t a r t>', 'Secretary'): 5,
#  ('<s t a r t>', 'Secretary', 'Clinton'): 1,
#  ('Secretary', 'Clinton', 'had'): 1,
#  ('Clinton', 'had', 'been'): 1,
#  ('had', 'been', 'calling'): 1,
#  ('been', 'calling', 'for'): 2,
#  ('calling', 'for', '<u n k>'): 1,
#  ('for', '<u n k>', 'and'): 60,
#  ('<u n k>', 'and', 'Lee'): 3,
#  ('and', 'Lee', 'to'): 1,
#  ('Lee', 'to', 'be'): 1,
#  ('to', 'be', 'released'): 10,
#  ('be', 'released', 'for'): 1,
#  ('released', 'for', 'months'): 1,
#  ('for', 'months', '.'): 6,
#  ('months', '.', '<s t o p>'): 102,
#  ('<s t a r t>', '<s t a r t>', 'But'): 1939,
#  ('<s t a r t>', 'But', 'in'): 59,
#  ('But', 'in', 'order'): 1,
#  ('in', 'order', 'to'): 72,
#  ('order', 'to', 'achieve'): 2,
#  ('to', 'achieve', 'that'): 2,
#  ('achieve', 'that', ','): 1,
#  ('that', ',', 'farmers'): 1,
#  (',', 'farmers', '--'): 1,
#  ('farmers', '--', 'homeless'): 1,
#  ('--', 'homeless', 'and'): 1,
#  ('homeless', 'and', 'hungry'): 1,
#  ('and', 'hungry', '--'): 1,
#  ('hungry', '--', 'need'): 1,
#  ('--', 'need', 'help'): 1,
#  ('need', 'help', '.'): 3,
#  ('help', '.', '<s t o p>'): 40,
#  ('<s t a r t>', '<s t a r t>', 'Three'): 69,
#  ('<s t a r t>', 'Three', 'former'): 1,
#  ('Three', 'former', 'England'): 1,
#  ('former', 'England', 'captains'): 1,
#  ('England', 'captains', ','): 1,
#  ('captains', ',', 'David'): 1,
#  (',', 'David', '<u n k>'): 15,
#  ('David', '<u n k>', ','): 52,
#  ('<u n k>', ',', 'Mike'): 3,
#  (',', 'Mike', '<u n k>'): 2,
#  ('Mike', '<u n k>', 'and'): 6,
#  ('<u n k>', 'and', '<u n k>'): 1046,
#  ('and', '<u n k>', 'Hussain'): 2,
#  ('<u n k>', 'Hussain', ','): 4,
#  ('Hussain', ',', 'have'): 1,
#  (',', 'have', 'now'): 1,
#  ('have', 'now', 'deplored'): 1,
#  ('now', 'deplored', 'here'): 1,
#  ('deplored', 'here', 'the'): 1,
#  ('here', 'the', 'decision'): 1,
#  ('the', 'decision', 'of'): 3,
#  ('decision', 'of', 'their'): 1,
#  ('of', 'their', 'successor'): 1,
#  ('their', 'successor', 'Andrew'): 1,
#  ('successor', 'Andrew', 'Strauss'): 1,
#  ('Andrew', 'Strauss', 'to'): 1,
#  ('Strauss', 'to', 'take'): 1,
#  ('to', 'take', 'a'): 49,
#  ('take', 'a', 'break'): 3,
#  ('a', 'break', 'from'): 10,
#  ('break', 'from', 'the'): 7,
#  ('from', 'the', 'tour'): 2,
#  ('the', 'tour', 'of'): 3,
#  ('tour', 'of', 'Bangladesh'): 2,
#  ('of', 'Bangladesh', '.'): 2,
#  ('Bangladesh', '.', '<s t o p>'): 5,
#  ('<s t a r t>', '<u n k>', 'are'): 94,
#  ('<u n k>', 'are', 'the'): 16,
#  ('are', 'the', 'official'): 1,
#  ('the', 'official', 'gambling'): 1,
#  ('official', 'gambling', 'partners'): 1,
#  ('gambling', 'partners', 'of'): 1,
#  ('partners', 'of', 'Chelsea'): 1,
#  ('of', 'Chelsea', 'and'): 1,
#  ('Chelsea', 'and', 'Aston'): 1,
#  ('and', 'Aston', 'Villa'): 1,
#  ('Aston', 'Villa', 'and'): 1,
#  ('Villa', 'and', 'the'): 1,
#  ('and', 'the', 'shirt'): 1,
#  ('the', 'shirt', 'sponsors'): 1,
#  ('shirt', 'sponsors', 'of'): 1,
#  ('sponsors', 'of', 'Bolton'): 1,
#  ('of', 'Bolton', 'and'): 1,
#  ('Bolton', 'and', 'Wigan'): 1,
#  ('and', 'Wigan', ','): 1,
#  ('Wigan', ',', 'while'): 1,
#  (',', 'while', '<u n k>'): 39,
#  ('while', '<u n k>', 'sponsor'): 1,
#  ('<u n k>', 'sponsor', 'the'): 1,
#  ('sponsor', 'the', 'shirts'): 1,
#  ('the', 'shirts', 'of'): 1,
#  ('shirts', 'of', 'West'): 1,
#  ('of', 'West', 'Ham'): 1,
#  ('West', 'Ham', 'and'): 2,
#  ('Ham', 'and', 'Cardiff'): 1,
#  ('and', 'Cardiff', '.'): 1,
#  ('Cardiff', '.', '<s t o p>'): 4,
#  ('<s t a r t>', '<s t a r t>', '"'): 3990,
#  ('<s t a r t>', '"', 'You'): 71,
#  ('"', 'You', 'said'): 1,
#  ('You', 'said', 'on'): 1,
#  ('said', 'on', 'June'): 1,
#  ('on', 'June', '2'): 1,
#  ('June', '2', 'that'): 1,
#  ('2', 'that', '<u n k>'): 1,
#  ('that', '<u n k>', '<u n k>'): 45,
#  ('<u n k>', '<u n k>', '['): 7,
#  ('<u n k>', '[', 'another'): 1,
#  ('[', 'another', 'defendant'): 1,
#  ('another', 'defendant', ']'): 1,
#  ('defendant', ']', 'met'): 1,
#  (']', 'met', 'with'): 1,
#  ('met', 'with', 'Gen.'): 1,
#  ('with', 'Gen.', '<u n k>'): 1,
#  ('Gen.', '<u n k>', '<u n k>'): 4,
#  ('<u n k>', '<u n k>', 'and'): 387,
#  ('<u n k>', 'and', 'discussed'): 2,
#  ('and', 'discussed', 'this'): 1,
#  ('discussed', 'this', 'plan'): 1,
#  ('this', 'plan', 'to'): 1,
#  ('plan', 'to', 'buy'): 1,
#  ('to', 'buy', 'weapons'): 1,
#  ('buy', 'weapons', 'and'): 1,
#  ('weapons', 'and', 'take'): 1,
#  ('and', 'take', 'them'): 4,
#  ('take', 'them', 'over'): 1,
#  ('them', 'over', 'and'): 2,
#  ('over', 'and', 'fight'): 1,
#  ('and', 'fight', 'a'): 1,
#  ('fight', 'a', 'war'): 1,
#  ('a', 'war', 'over'): 1,
#  ('war', 'over', 'there'): 1,
#  ('over', 'there', '--'): 1,
#  ('there', '--', 'right'): 1,
#  ('--', 'right', '?'): 1,
#  ('right', '?', '"'): 1,
#  ('?', '"', '<s t o p>'): 40,
#  ('<s t a r t>', 'A', '<u n k>'): 142,
#  ('A', '<u n k>', 'spokesman'): 4,
#  ('<u n k>', 'spokesman', 'said'): 5,
#  ('said', 'the', 'worker'): 1,
#  ('the', 'worker', 'who'): 1,
#  ('worker', 'who', 'had'): 1,
#  ('who', 'had', 'cut'): 1,
#  ('had', 'cut', 'his'): 2,
#  ('cut', 'his', 'finger'): 1,
#  ('his', 'finger', 'was'): 1,
#  ...}

# %%
# Get the bigram counts for each word in the vocabulary
cnt_bi = {}
cnt_half_bi = 0
f_name = "" # The path of the file that contains that training tokens. In my case it is of sentences form line by line.
with open(f_name) as file:
  for line in file:
    arr = [('<s t a r t>', '<s t a r t>')] + token_bi(line, word_dict)
    for bi in arr:
      if bi not in cnt_bi:
        cnt_bi[bi] = 1
      else:
        cnt_bi[bi] += 1

cnt_bi
# Out:
# {('<s t a r t>', '<s t a r t>'): 61530,
#  ('<s t a r t>', 'Having'): 43,
#  ('Having', 'a'): 4,
#  ('a', 'little'): 165,
#  ('little', 'flexibility'): 1,
#  ('flexibility', 'on'): 1,
#  ('on', 'that'): 46,
#  ('that', 'issue'): 5,
#  ('issue', 'would'): 4,
#  ('would', 'go'): 26,
#  ('go', 'a'): 2,
#  ('a', 'long'): 117,
#  ('long', 'way'): 16,
#  ('way', 'to'): 170,
#  ('to', 'putting'): 3,
#  ('putting', 'together'): 4,
#  ('together', 'a'): 11,
#  ('a', 'final'): 30,
#  ('final', 'package'): 1,
#  ('package', '.'): 11,
#  ('.', '<s t o p>'): 58015,
#  ('<s t a r t>', 'Long'): 9,
#  ('Long', 'before'): 3,
#  ('before', 'the'): 296,
#  ('the', 'advent'): 4,
#  ('advent', 'of'): 5,
#  ('of', 'e-commerce'): 1,
#  ('e-commerce', ','): 2,
#  (',', 'Wal-Mart'): 5,
#  ('Wal-Mart', "'s"): 2,
#  ("'s", 'founder'): 7,
#  ('founder', 'Sam'): 1,
#  ('Sam', 'Walton'): 1,
#  ('Walton', 'set'): 1,
#  ('set', 'out'): 21,
#  ('out', 'his'): 18,
#  ('his', 'vision'): 7,
#  ('vision', 'for'): 9,
#  ('for', 'a'): 1086,
#  ('a', 'successful'): 18,
#  ('successful', 'retail'): 1,
#  ('retail', 'operation'): 1,
#  ('operation', ':'): 1,
#  (':', '"'): 503,
#  ('"', 'We'): 510,
#  ('We', 'let'): 1,
#  ('let', 'folks'): 1,
#  ('folks', 'know'): 1,
#  ('know', 'we'): 3,
#  ('we', "'re"): 120,
#  ("'re", 'interested'): 2,
#  ('interested', 'in'): 48,
#  ('in', 'them'): 11,
#  ('them', 'and'): 23,
#  ('and', 'that'): 336,
#  ('that', 'they'): 334,
#  ('they', "'re"): 124,
#  ("'re", 'vital'): 1,
#  ('vital', 'to'): 9,
#  ('to', '<u n k>'): 2052,
#  ('<u n k>', "'"): 296,
#  ("'", 'cause'): 3,
#  ('cause', 'they'): 1,
#  ('they', 'are'): 352,
#  ('are', ','): 34,
#  (',', '"'): 4616,
#  ('"', 'he'): 796,
#  ('he', 'said'): 814,
#  ('said', '.'): 2305,
#  ('<s t a r t>', 'A'): 1421,
#  ('A', 'spokesman'): 43,
#  ('spokesman', 'said'): 80,
#  ('said', 'the'): 894,
#  ('the', 'company'): 360,
#  ('company', 'has'): 30,
#  ('has', 'been'): 1140,
#  ('been', 'affected'): 8,
#  ('affected', 'by'): 37,
#  ('by', 'the'): 1459,
#  ('the', 'credit'): 47,
#  ('credit', 'crunch'): 27,
#  ('crunch', 'in'): 2,
#  ('in', 'the'): 7213,
#  ('the', 'United'): 527,
#  ('United', 'States'): 511,
#  ('States', '.'): 86,
#  ('<s t a r t>', 'Abu'): 8,
#  ('Abu', 'Dhabi'): 20,
#  ('Dhabi', 'is'): 2,
#  ('is', 'going'): 75,
#  ('going', 'ahead'): 3,
#  ('ahead', 'to'): 8,
#  ('to', 'build'): 107,
#  ('build', 'solar'): 1,
#  ('solar', 'city'): 1,
#  ('city', 'and'): 23,
#  ('and', 'no'): 51,
#  ('no', 'pollution'): 1,
#  ('pollution', 'city'): 1,
#  ('city', '.'): 47,
#  ('<s t a r t>', 'Her'): 130,
#  ('Her', 'back'): 1,
#  ('back', 'was'): 1,
#  ('was', 'torn'): 4,
#  ('torn', 'open'): 1,
#  ('open', ','): 17,
#  (',', 'her'): 65,
#  ('her', 'liver'): 3,
#  ('liver', 'was'): 1,
#  ('was', 'ruptured'): 1,
#  ('ruptured', ','): 2,
#  (',', 'one'): 232,
#  ('one', 'of'): 873,
#  ('of', 'her'): 181,
#  ('her', 'lungs'): 2,
#  ('lungs', 'had'): 1,
#  ('had', 'collapsed'): 5,
#  ('collapsed', 'and'): 7,
#  ('and', 'the'): 1988,
#  ('the', 'other'): 229,
#  ('other', 'was'): 2,
#  ('was', '<u n k>'): 419,
#  ('<u n k>', '.'): 5937,
#  ('<s t a r t>', 'Now'): 180,
#  ('Now', 'it'): 8,
#  ('it', 'has'): 198,
#  ('has', '175'): 1,
#  ('175', 'staging'): 1,
#  ('staging', 'centers'): 1,
#  ('centers', ','): 7,
#  (',', 'where'): 430,
#  ('where', 'volunteers'): 1,
#  ('volunteers', 'are'): 2,
#  ('are', 'coordinating'): 1,
#  ('coordinating', 'get-out-the-vote'): 1,
#  ('get-out-the-vote', 'efforts'): 2,
#  ('efforts', ','): 17,
#  (',', 'said'): 1062,
#  ('said', 'Obama'): 12,
#  ('Obama', "'s"): 213,
#  ("'s", 'Georgia'): 1,
#  ('Georgia', 'spokeswoman'): 1,
#  ('spokeswoman', ','): 6,
#  (',', 'Caroline'): 2,
#  ('Caroline', '<u n k>'): 6,
#  ('<s t a r t>', 'How'): 106,
#  ('How', 'about'): 15,
#  ('about', 'a'): 129,
#  ('a', '<u n k>'): 3778,
#  ('<u n k>', 'or'): 363,
#  ('or', 'family'): 3,
#  ('family', 'friend'): 4,
#  ('friend', '?'): 1,
#  ('?', '<s t o p>'): 1344,
#  ('<s t a r t>', 'Butler'): 7,
#  ('Butler', "'s"): 3,
#  ("'s", 'the'): 126,
#  ('the', 'scorer'): 1,
#  ('scorer', '.'): 1,
#  ('<s t a r t>', 'In'): 1744,
#  ('In', 'the'): 372,
#  ('the', 'meantime'): 19,
#  ('meantime', ','): 14,
#  (',', 'the'): 4774,
#  ('the', '<u n k>'): 6725,
#  ('<u n k>', 'Bell'): 6,
#  ('Bell', 'gets'): 1,
#  ('gets', 'to'): 10,
#  ('to', 'showcase'): 3,
#  ('showcase', 'her'): 1,
#  ('her', 'musical'): 1,
#  ('musical', '<u n k>'): 7,
#  ('<u n k>', 'during'): 75,
#  ('during', 'the'): 373,
#  ('the', 'end'): 361,
#  ('end', 'credits'): 1,
#  ('credits', 'of'): 3,
#  ('of', '"'): 211,
#  ('"', 'When'): 55,
#  ('When', 'in'): 1,
#  ('in', 'Rome'): 16,
#  ('Rome', '"'): 1,
#  ('"', 'when'): 24,
#  ('when', 'the'): 315,
#  ('the', 'cast'): 11,
#  ('cast', 'breaks'): 1,
#  ('breaks', 'in'): 7,
#  ('in', 'to'): 61,
#  ('to', 'a'): 1097,
#  ('a', 'musical'): 8,
#  ('musical', 'dance'): 1,
#  ('dance', 'number'): 1,
#  ('number', '.'): 7,
#  ('<s t a r t>', 'McCain'): 58,
#  ('McCain', 'said'): 7,
#  ('said', 'he'): 473,
#  ('he', 'must'): 8,
#  ('must', 'convince'): 2,
#  ('convince', 'Americans'): 2,
#  ('Americans', 'that'): 5,
#  ('that', '"'): 102,
#  ('"', 'protectionism'): 1,
#  ('protectionism', 'and'): 3,
#  ('and', '<u n k>'): 3383,
#  ('<u n k>', '"'): 967,
#  ('"', 'could'): 12,
#  ('could', 'be'): 373,
#  ('be', 'harmful'): 1,
#  ('harmful', '.'): 2,
#  ('<s t a r t>', 'He'): 1802,
#  ('He', 'knew'): 5,
#  ('knew', 'that'): 17,
#  ('that', 'this'): 108,
#  ('this', '<u n k>'): 125,
#  ('<u n k>', 'process'): 24,
#  ('process', 'is'): 7,
#  ('is', 'simply'): 14,
#  ('simply', 'what'): 1,
#  ('what', 'the'): 81,
#  ('the', 'soul'): 4,
#  ('soul', '--'): 1,
#  ('--', 'or'): 40,
#  ('or', 'true'): 2,
#  ('true', 'self'): 1,
#  ('self', ','): 4,
#  (',', 'if'): 204,
#  ('if', 'you'): 150,
#  ('you', 'prefer'): 4,
#  ('prefer', '--'): 1,
#  ('--', 'does'): 1,
#  ('does', 'when'): 1,
#  ('when', 'we'): 42,
#  ('we', 'stop'): 3,
#  ('stop', '<u n k>'): 10,
#  ('<s t a r t>', '15'): 14,
#  ('15', 'at'): 3,
#  ('at', 'Carolina'): 1,
#  ('Carolina', 'Panthers'): 1,
#  ('Panthers', 'FOX'): 1,
#  ('FOX', '1'): 1,
#  ('1', 'p.m.'): 7,
#  ('p.m.', '<s t o p>'): 71,
#  ('<s t a r t>', 'Marc'): 5,
#  ('Marc', 'D.'): 1,
#  ('D.', '<u n k>'): 10,
#  ('<u n k>', ','): 11508,
#  ('the', 'lawyer'): 9,
#  ('lawyer', 'who'): 5,
#  ('who', 'represents'): 6,
#  ('represents', 'David'): 1,
#  ('David', 'M.'): 2,
#  ('M.', '<u n k>'): 16,
#  ('the', 'licensed'): 1,
#  ('licensed', 'massage'): 1,
#  ('massage', 'therapist'): 1,
#  ('therapist', 'who'): 1,
#  ('who', 'is'): 210,
#  ('is', '<u n k>'): 442,
#  ('<u n k>', "'s"): 1662,
#  ("'s", 'former'): 37,
#  ('former', 'vice'): 4,
#  ('vice', 'president'): 44,
#  ('president', ','): 80,
#  ('he', 'had'): 300,
#  ('had', 'sent'): 9,
#  ('sent', 'a'): 35,
#  ('a', 'letter'): 45,
#  ('letter', 'to'): 31,
#  ('to', 'Congress'): 19,
#  ('Congress', 'saying'): 1,
#  ('saying', 'Mr.'): 1,
#  ('Mr.', '<u n k>'): 294,
#  ('<u n k>', 'would'): 135,
#  ('would', 'speak'): 1,
#  ('speak', 'publicly'): 2,
#  ('publicly', 'only'): 1,
#  ('only', 'if'): 14,
#  ('if', 'he'): 118,
#  ('he', 'was'): 677,
#  ('was', 'granted'): 6,
#  ('granted', 'immunity'): 2,
#  ('immunity', 'from'): 6,
#  ('from', 'prosecution'): 5,
#  ('prosecution', '.'): 8,
#  ('<u n k>', 'of'): 2262,
#  ('of', 'circus'): 1,
#  ('circus', 'and'): 1,
#  ('and', 'variety'): 2,
#  ('variety', 'history'): 1,
#  ('history', ','): 51,
#  (',', 'no'): 105,
#  ('no', 'family'): 1,
#  ('family', 'better'): 1,
#  ('better', 'deserved'): 1,
#  ('deserved', 'the'): 2,
#  ('the', 'description'): 2,
#  ('description', 'of'): 9,
#  ('"', 'the'): 419,
#  ('the', 'royal'): 7,
#  ('royal', 'family'): 6,
#  ('family', 'of'): 18,
#  ('of', '<u n k>'): 3193,
#  ('"', 'than'): 10,
#  ('than', 'did'): 3,
#  ('did', 'the'): 27,
#  ('<s t a r t>', 'One'): 279,
#  ('One', 'of'): 115,
#  ('of', 'the'): 8342,
#  ('the', 'defendants'): 11,
#  ('defendants', 'was'): 1,
#  ('was', 'found'): 88,
#  ('found', 'not'): 3,
#  ('not', 'guilty'): 16,
#  ('guilty', 'and'): 2,
#  ('the', 'jury'): 26,
#  ('jury', 'was'): 5,
#  ('was', 'unable'): 20,
#  ('unable', 'to'): 78,
#  ('to', 'reach'): 96,
#  ('reach', 'a'): 21,
#  ('a', 'verdict'): 6,
#  ('verdict', 'for'): 2,
#  ('for', 'four'): 29,
#  ('four', 'other'): 10,
#  ('other', 'men'): 11,
#  ('men', 'on'): 2,
#  ('on', 'trial'): 14,
#  ('trial', '.'): 32,
#  ('<s t a r t>', 'Nursing'): 1,
#  ('Nursing', 'Homes'): 1,
#  ('Homes', ':'): 1,
#  (':', '<u n k>'): 302,
#  ("'s", '2009'): 3,
#  ('2009', 'Cost'): 1,
#  ('Cost', 'of'): 2,
#  ('of', 'Care'): 1,
#  ('Care', 'Survey'): 1,
#  ('Survey', 'analyzed'): 1,
#  ('analyzed', 'long'): 1,
#  ('long', 'term'): 20,
#  ('term', 'care'): 2,
#  ('care', 'costs'): 5,
#  ('costs', 'in'): 5,
#  ('in', 'two'): 73,
#  ('two', 'regions'): 1,
#  ('regions', 'in'): 3,
#  ('in', 'Hawaii'): 5,
#  ('Hawaii', ':'): 1,
#  ('<u n k>', 'and'): 3903,
#  ('the', 'rest'): 122,
#  ('rest', 'of'): 113,
#  ('the', 'state'): 270,
#  ('state', '.'): 51,
#  ('<s t a r t>', 'Players'): 8,
#  ('Players', 'can'): 1,
#  ('can', 'take'): 31,
#  ('take', 'their'): 20,
#  ('their', 'performances'): 2,
#  ('performances', 'to'): 1,
#  ('to', 'the'): 3457,
#  ('the', 'next'): 296,
#  ('next', 'level'): 2,
#  ('level', 'by'): 2,
#  ('by', 'turning'): 2,
#  ('turning', 'their'): 1,
#  ('their', 'best'): 19,
#  ('best', '30'): 1,
#  ('30', 'second'): 1,
#  ('second', 'clips'): 1,
#  ('clips', 'into'): 1,
#  ('into', 'their'): 39,
#  ('their', 'own'): 166,
#  ('own', 'mini'): 1,
#  ('mini', 'music'): 1,
#  ('music', 'videos'): 2,
#  ('videos', 'using'): 1,
#  ('using', 'a'): 29,
#  ('a', 'selection'): 7,
#  ('selection', 'of'): 19,
#  ('of', 'special'): 4,
#  ('special', 'editing'): 1,
#  ('editing', 'effects'): 1,
#  ('effects', '.'): 7,
#  ('<s t a r t>', '<u n k>'): 6782,
#  ('<u n k>', 'came'): 39,
#  ('came', 'in'): 39,
#  ('in', 'fifth'): 3,
#  ('fifth', '.'): 5,
#  ('<s t a r t>', "'"): 25,
#  ("'", 'Coming'): 1,
#  ('Coming', 'Home'): 2,
#  ('Home', "'"): 1,
#  ("'", 'was'): 5,
#  ('was', 'released'): 35,
#  ('released', 'in'): 18,
#  ('in', 'October'): 82,
#  ('October', 'last'): 5,
#  ('last', 'year'): 482,
#  ('year', '.'): 508,
#  ('<s t a r t>', 'Bush'): 32,
#  ('Bush', 'is'): 17,
#  ('is', 'remembered'): 3,
#  ('remembered', 'by'): 4,
#  ('by', 'many'): 18,
#  ('many', 'Haitians'): 1,
#  ('Haitians', '--'): 1,
#  ('--', 'especially'): 8,
#  ('especially', 'the'): 10,
#  ('the', 'thousands'): 22,
#  ('thousands', 'in'): 3,
#  ('in', 'Port-au-Prince'): 8,
#  ('Port-au-Prince', "'s"): 1,
#  ("'s", '<u n k>'): 1330,
#  ('<u n k>', 'slums'): 2,
#  ('slums', '--'): 1,
#  ('--', 'as'): 48,
#  ('as', 'the'): 849,
#  ('the', 'U.S.'): 433,
#  ('U.S.', 'leader'): 1,
#  ('leader', 'whose'): 1,
#  ('whose', 'administration'): 1,
#  ('administration', '<u n k>'): 4,
#  ('<u n k>', 'the'): 1368,
#  ('the', 'plane'): 36,
#  ('plane', 'that'): 5,
#  ('that', 'flew'): 4,
#  ('flew', '<u n k>'): 1,
#  ('<u n k>', 'back'): 41,
#  ('back', 'into'): 36,
#  ('into', 'exile'): 6,
#  ('exile', 'during'): 1,
#  ('during', 'a'): 136,
#  ('a', '2004'): 8,
#  ('2004', 'rebellion'): 1,
#  ('rebellion', '.'): 3,
#  ('<s t a r t>', 'Last'): 178,
#  ('Last', 'week'): 50,
#  ('week', 'top'): 1,
#  ('top', 'US'): 9,
#  ('US', 'military'): 16,
#  ('military', 'officer'): 4,
#  ('officer', 'Admiral'): 1,
#  ('Admiral', 'Mike'): 2,
#  ('Mike', 'Mullen'): 4,
#  ('Mullen', 'said'): 1,
#  ('said', 'this'): 31,
#  ('this', 'increased'): 1,
#  ('increased', 'the'): 12,
#  ('the', 'flow'): 18,
#  ('flow', 'of'): 22,
#  ('of', 'militants'): 7,
#  ('militants', 'into'): 1,
#  ('into', 'Afghanistan'): 4,
#  ('Afghanistan', 'to'): 5,
#  ('to', 'combat'): 27,
#  ('combat', 'Nato'): 1,
#  ('Nato', 'troops'): 2,
#  ('troops', '.'): 20,
#  ('<u n k>', 'Inc'): 35,
#  ('Inc', '.'): 147,
#  ('.', ','): 378,
#  ('the', 'petroleum'): 1,
#  ('petroleum', 'refining'): 1,
#  ('refining', 'company'): 1,
#  ('company', ','): 97,
#  ('said', 'on'): 123,
#  ('on', 'Wednesday'): 292,
#  ('Wednesday', 'that'): 41,
#  ('that', 'it'): 443,
#  ('it', 'had'): 144,
#  ('had', 'hired'): 4,
#  ('hired', 'Lynn'): 1,
#  ('Lynn', '<u n k>'): 5,
#  ('<u n k>', '<u n k>'): 8032,
#  ('<u n k>', 'as'): 383,
#  ('as', 'its'): 27,
#  ('its', 'chief'): 7,
#  ('chief', 'executive'): 179,
#  ('executive', ','): 43,
#  (',', 'succeeding'): 2,
#  ('succeeding', 'John'): 1,
#  ('John', '<u n k>'): 131,
#  (',', 'who'): 1677,
#  ('is', 'retiring'): 1,
#  ('retiring', 'in'): 1,
#  ('in', 'August'): 79,
#  ('August', '.'): 36,
#  ('<s t a r t>', 'Under'): 96,
#  ('Under', 'the'): 62,
#  ('the', 'terms'): 28,
#  ('terms', 'of'): 69,
#  ('the', 'agreement'): 19,
#  ('agreement', ','): 22,
#  (',', '<u n k>'): 4608,
#  ('<u n k>', 'was'): 764,
#  ('was', 'paid'): 10,
#  ('paid', 'an'): 4,
#  ('an', 'annual'): 22,
#  ('annual', 'consulting'): 1,
#  ('consulting', 'fee'): 1,
#  ('fee', 'of'): 2,
#  ('of', '$'): 213,
#  ('$', '50,000'): 11,
#  ('50,000', 'and'): 1,
#  ('and', 'entitled'): 1,
#  ('entitled', 'to'): 18,
#  ('to', '120'): 7,
#  ('120', 'hours'): 1,
#  ('hours', 'per'): 4,
#  ('per', 'year'): 23,
#  ('year', 'of'): 33,
#  ('of', 'flying'): 3,
#  ('flying', 'time'): 1,
#  ('time', 'on'): 17,
#  ('on', 'a'): 755,
#  ('a', 'corporate'): 4,
#  ('corporate', 'jet'): 1,
#  ('jet', 'provided'): 1,
#  ('provided', 'by'): 26,
#  ('by', 'BofA'): 1,
#  ('BofA', '.'): 1,
#  ('<s t a r t>', 'The'): 8913,
#  ('The', '<u n k>'): 1158,
#  ('<u n k>', 'surrounding'): 5,
#  ('surrounding', 'the'): 13,
#  ('<u n k>', 'even'): 14,
#  ('even', 'forced'): 2,
#  ('forced', '<u n k>'): 6,
#  ('<u n k>', 'to'): 1602,
#  ('to', 'ensure'): 98,
#  ('ensure', 'the'): 22,
#  ('the', 'Olympics'): 14,
#  ('Olympics', 'would'): 3,
#  ('would', 'not'): 227,
#  ('not', 'be'): 277,
#  ('be', 'a'): 387,
#  ('a', 'battle'): 12,
#  ('battle', 'of'): 7,
#  ('<u n k>', 'against'): 73,
#  ('against', '<u n k>'): 92,
#  ('<u n k>', '-'): 189,
#  ('-', 'particularly'): 2,
#  ('particularly', 'when'): 4,
#  ('<u n k>', 'has'): 557,
#  ('has', 'a'): 259,
#  ('a', 'price'): 14,
#  ('price', 'tag'): 10,
#  ('tag', 'of'): 1,
#  ('$', '550'): 4,
#  ('550', '('): 1,
#  ('(', '£'): 70,
#  ('£', '<u n k>'): 480,
#  ('<u n k>', ')'): 1116,
#  (')', '-'): 639,
#  ('-', 'by'): 6,
#  ('by', 'allowing'): 10,
#  ('allowing', 'all'): 1,
#  ('all', 'of'): 158,
#  ('the', 'major'): 32,
#  ('major', 'manufacturers'): 2,
#  ('manufacturers', 'to'): 5,
#  ('to', 'hand'): 20,
#  ('hand', 'out'): 5,
#  ('out', 'suits'): 1,
#  ('suits', 'to'): 3,
#  ('to', 'national'): 4,
#  ('national', 'teams'): 1,
#  ('teams', '.'): 15,
#  ('<s t a r t>', 'Barr'): 3,
#  ('Barr', 'Pharmaceuticals'): 1,
#  ('Pharmaceuticals', 'said'): 1,
#  ('said', 'Friday'): 44,
#  ('Friday', 'that'): 30,
#  ('it', 'planned'): 9,
#  ('planned', 'to'): 68,
#  ('to', 'introduce'): 18,
#  ('introduce', 'its'): 1,
#  ('its', 'generic'): 2,
#  ('generic', 'version'): 2,
#  ('version', 'of'): 105,
#  ('the', 'basic'): 13,
#  ('basic', '<u n k>'): 3,
#  ('<u n k>', 'form'): 11,
#  ('form', 'of'): 67,
#  ('<u n k>', 'on'): 803,
#  ('on', 'Feb'): 15,
#  ('Feb', '.'): 41,
#  ('<s t a r t>', 'Qatar'): 3,
#  ('Qatar', "'s"): 2,
#  ("'s", 'economy'): 22,
#  ('economy', ','): 82,
#  (',', 'which'): 1948,
#  ('which', 'has'): 177,
#  ('has', 'bucked'): 2,
#  ('bucked', 'the'): 3,
#  ('the', 'regional'): 17,
#  ('regional', 'recession'): 1,
#  ('recession', ','): 29,
#  (',', 'should'): 34,
#  ('should', 'grow'): 2,
#  ('grow', 'by'): 8,
#  ('by', 'about'): 13,
#  ('about', '9'): 3,
#  ('9', 'per'): 3,
#  ('per', 'cent'): 471,
#  ('cent', 'this'): 3,
#  ('this', 'year'): 443,
#  ('year', 'and'): 71,
#  ('and', 'revenues'): 4,
#  ('revenues', 'will'): 2,
#  ('will', 'jump'): 1,
#  ('jump', 'by'): 3,
#  ('end', 'of'): 342,
#  ('of', 'next'): 25,
#  ('next', 'year'): 131,
#  ('year', 'as'): 24,
#  ('as', 'gas'): 1,
#  ('gas', 'exports'): 3,
#  ('exports', 'almost'): 1,
#  ('almost', 'double'): 3,
#  ('double', '.'): 9,
#  ('<s t a r t>', 'Although'): 140,
#  ('Although', 'not'): 4,
#  ('not', 'yet'): 59,
#  ('yet', 'a'): 2,
#  ('a', 'household'): 3,
#  ('household', 'name'): 2,
#  ('name', ','): 27,
#  (',', 'Kyle'): 1,
#  ('Kyle', '<u n k>'): 12,
#  ('and', 'Associates'): 3,
#  ('Associates', 'is'): 1,
#  ('is', 'at'): 48,
#  ('at', 'the'): 2176,
#  ('the', 'cutting'): 3,
#  ('cutting', 'edge'): 8,
#  ('edge', 'of'): 29,
#  ('the', 'rapidly'): 6,
#  ('rapidly', 'growing'): 2,
#  ('growing', 'online'): 1,
#  ('online', 'business'): 1,
#  ('business', 'arena'): 1,
#  ('arena', ';'): 1,
#  (';', 'and'): 127,
#  ('and', 'this'): 39,
#  ('this', 'at'): 4,
#  ('the', 'announcement'): 24,
#  ('announcement', 'of'): 17,
#  ('of', 'his'): 603,
#  ('his', 'new'): 34,
#  ('new', 'joint'): 1,
#  ('joint', 'venture'): 26,
#  ('venture', 'with'): 8,
#  ('with', '<u n k>'): 735,
#  ('<u n k>', 'Express'): 6,
#  ('Express', '.'): 4,
#  ('<s t a r t>', 'Officials'): 62,
#  ('Officials', 'fear'): 2,
#  ('fear', 'that'): 19,
#  ('that', 'bulls'): 1,
#  ('bulls', 'are'): 2,
#  ('are', 'being'): 104,
#  ('being', '<u n k>'): 65,
#  ('<u n k>', 'with'): 746,
#  ('to', 'make'): 493,
#  ('make', 'them'): 13,
#  ('them', 'less'): 1,
#  ('less', 'aggressive'): 3,
#  ('aggressive', ','): 6,
#  (',', 'giving'): 48,
#  ('giving', 'the'): 13,
#  ('<u n k>', 'a'): 590,
#  ('a', 'crucial'): 12,
#  ('crucial', 'edge'): 1,
#  ('edge', 'in'): 7,
#  ('the', 'contest'): 17,
#  ('contest', '.'): 11,
#  ('The', 'Interior'): 2,
#  ('Interior', 'Department'): 5,
#  ('Department', "'s"): 20,
#  ("'s", 'Minerals'): 1,
#  ('Minerals', 'Management'): 2,
#  ('Management', 'Service'): 3,
#  ('Service', 'said'): 12,
#  ('said', 'yesterday'): 21,
#  ('yesterday', 'that'): 29,
#  ('that', 'only'): 29,
#  ('only', '61'): 1,
#  ('61', 'percent'): 6,
#  ('percent', 'of'): 299,
#  ('of', 'oil'): 34,
#  ('oil', 'production'): 11,
#  ('production', 'in'): 8,
#  ('the', 'Gulf'): 33,
#  ('Gulf', 'of'): 16,
#  ('of', 'Mexico'): 16,
#  ('Mexico', 'has'): 3,
#  ('been', 'restored'): 3,
#  ('restored', 'as'): 1,
#  ('as', 'companies'): 5,
#  ('companies', 'struggle'): 2,
#  ('struggle', 'with'): 7,
#  ('with', 'repairs'): 1,
#  ('repairs', 'to'): 4,
#  ('to', 'platforms'): 2,
#  ('platforms', '.'): 4,
#  ('<s t a r t>', 'And'): 778,
#  ('And', 'finally'): 8,
#  ('finally', 'for'): 1,
#  ('for', 'MTV'): 1,
#  ('MTV', ','): 1,
#  (',', 'they'): 452,
#  ('they', 'have'): 235,
#  ('have', 'produced'): 7,
#  ('produced', 'the'): 9,
#  ('the', 'most'): 485,
#  ('most', 'talked'): 3,
#  ('talked', 'about'): 19,
#  ('about', '<u n k>'): 192,
#  ('<u n k>', 'since'): 43,
#  ('since', 'that'): 5,
#  ('that', 'Jackson'): 1,
#  ('Jackson', 'and'): 6,
#  ('and', 'Presley'): 1,
#  ('Presley', 'kiss'): 1,
#  ('kiss', '.'): 1,
#  ('<u n k>', 'Czech'): 2,
#  ('Czech', 'leader'): 1,
#  ('leader', ','): 47,
#  ('the', 'last'): 381,
#  ('last', 'hurdle'): 1,
#  ('hurdle', 'for'): 2,
#  ('a', 'treaty'): 8,
#  ('treaty', 'that'): 6,
#  ('that', 'has'): 165,
#  ('has', 'taken'): 38,
#  ('taken', 'eight'): 2,
#  ('eight', 'years'): 45,
#  ('years', 'to'): 49,
#  ('to', 'stumble'): 3,
#  ('stumble', 'to'): 1,
#  ('the', 'finishing'): 2,
#  ('finishing', 'tape'): 1,
#  ('tape', ','): 4,
#  (',', 'insists'): 3,
#  ('insists', 'that'): 8,
#  ('that', 'the'): 1606,
#  ('the', 'EU'): 85,
#  ('EU', 'must'): 1,
#  ('must', 'first'): 5,
#  ('first', 'grant'): 1,
#  ('grant', 'the'): 1,
#  ('the', 'Czech'): 23,
#  ('Czech', 'Republic'): 25,
#  ('Republic', 'an'): 1,
#  ('an', '<u n k>'): 673,
#  ('He', 'said'): 260,
#  ('said', ':'): 309,
#  ('"', 'I'): 651,
#  ('I', "'m"): 328,
#  ("'m", 'extremely'): 3,
#  ('extremely', 'sorry'): 1,
#  ('sorry', 'to'): 5,
#  ('to', 'hear'): 45,
#  ('hear', 'that'): 5,
#  ('that', 'a'): 210,
#  ('a', 'young'): 57,
#  ('young', 'lad'): 1,
#  ('lad', 'has'): 1,
#  ('has', 'passed'): 12,
#  ('passed', 'away'): 2,
#  ('away', 'in'): 20,
#  ('in', 'such'): 31,
#  ('such', 'a'): 138,
#  ('a', 'tragic'): 7,
#  ('tragic', 'way'): 1,
#  ('way', '.'): 78,
#  ('<s t a r t>', 'Secretary'): 5,
#  ('Secretary', 'Clinton'): 1,
#  ('Clinton', 'had'): 5,
#  ('had', 'been'): 632,
#  ('been', 'calling'): 4,
#  ('calling', 'for'): 44,
#  ('for', '<u n k>'): 770,
#  ('and', 'Lee'): 7,
#  ('Lee', 'to'): 2,
#  ('to', 'be'): 1961,
#  ('be', 'released'): 36,
#  ('released', 'for'): 1,
#  ('for', 'months'): 28,
#  ('months', '.'): 106,
#  ('<s t a r t>', 'But'): 1939,
#  ('But', 'in'): 60,
#  ('in', 'order'): 81,
#  ('order', 'to'): 87,
#  ('to', 'achieve'): 37,
#  ('achieve', 'that'): 3,
#  ('that', ','): 235,
#  (',', 'farmers'): 3,
#  ('farmers', '--'): 1,
#  ('--', 'homeless'): 1,
#  ('homeless', 'and'): 4,
#  ('and', 'hungry'): 1,
#  ('hungry', '--'): 1,
#  ('--', 'need'): 2,
#  ('need', 'help'): 5,
#  ('help', '.'): 41,
#  ('<s t a r t>', 'Three'): 69,
#  ('Three', 'former'): 1,
#  ('former', 'England'): 4,
#  ('England', 'captains'): 1,
#  ('captains', ','): 1,
#  (',', 'David'): 27,
#  ('David', '<u n k>'): 124,
#  (',', 'Mike'): 8,
#  ('Mike', '<u n k>'): 50,
#  ('<u n k>', 'Hussain'): 6,
#  ('Hussain', ','): 4,
#  (',', 'have'): 171,
#  ('have', 'now'): 21,
#  ('now', 'deplored'): 1,
#  ('deplored', 'here'): 1,
#  ('here', 'the'): 3,
#  ('the', 'decision'): 68,
#  ('decision', 'of'): 6,
#  ('of', 'their'): 381,
#  ('their', 'successor'): 1,
#  ('successor', 'Andrew'): 1,
#  ('Andrew', 'Strauss'): 8,
#  ('Strauss', 'to'): 1,
#  ('to', 'take'): 352,
#  ('take', 'a'): 84,
#  ('a', 'break'): 28,
#  ('break', 'from'): 16,
#  ('from', 'the'): 1562,
#  ('the', 'tour'): 11,
#  ('tour', 'of'): 31,
#  ('of', 'Bangladesh'): 5,
#  ('Bangladesh', '.'): 5,
#  ('<u n k>', 'are'): 469,
#  ('are', 'the'): 165,
#  ('the', 'official'): 65,
#  ('official', 'gambling'): 1,
#  ('gambling', 'partners'): 1,
#  ('partners', 'of'): 2,
#  ('of', 'Chelsea'): 3,
#  ('Chelsea', 'and'): 5,
#  ('and', 'Aston'): 1,
#  ('Aston', 'Villa'): 9,
#  ('Villa', 'and'): 1,
#  ('the', 'shirt'): 1,
#  ('shirt', 'sponsors'): 1,
#  ('sponsors', 'of'): 2,
#  ('of', 'Bolton'): 2,
#  ('Bolton', 'and'): 3,
#  ('and', 'Wigan'): 3,
#  ('Wigan', ','): 3,
#  (',', 'while'): 376,
#  ('while', '<u n k>'): 90,
#  ('<u n k>', 'sponsor'): 1,
#  ('sponsor', 'the'): 1,
#  ('the', 'shirts'): 1,
#  ('shirts', 'of'): 2,
#  ('of', 'West'): 12,
#  ('West', 'Ham'): 19,
#  ('Ham', 'and'): 2,
#  ('and', 'Cardiff'): 5,
#  ('Cardiff', '.'): 4,
#  ('<s t a r t>', '"'): 3990,
#  ('"', 'You'): 93,
#  ('You', 'said'): 1,
#  ('on', 'June'): 34,
#  ('June', '2'): 3,
#  ('2', 'that'): 1,
#  ('that', '<u n k>'): 560,
#  ('<u n k>', '['): 30,
#  ('[', 'another'): 1,
#  ('another', 'defendant'): 1,
#  ('defendant', ']'): 1,
#  (']', 'met'): 1,
#  ('met', 'with'): 37,
#  ('with', 'Gen.'): 2,
#  ('Gen.', '<u n k>'): 7,
#  ('and', 'discussed'): 3,
#  ('discussed', 'this'): 1,
#  ('this', 'plan'): 4,
#  ('plan', 'to'): 113,
#  ('to', 'buy'): 131,
#  ('buy', 'weapons'): 1,
#  ('weapons', 'and'): 12,
#  ('and', 'take'): 28,
#  ('take', 'them'): 13,
#  ('them', 'over'): 4,
#  ('over', 'and'): 20,
#  ('and', 'fight'): 5,
#  ('fight', 'a'): 4,
#  ('a', 'war'): 28,
#  ('war', 'over'): 5,
#  ('over', 'there'): 3,
#  ('there', '--'): 3,
#  ('--', 'right'): 2,
#  ('right', '?'): 11,
#  ('?', '"'): 94,
#  ('"', '<s t o p>'): 1209,
#  ('A', '<u n k>'): 204,
#  ('<u n k>', 'spokesman'): 17,
#  ('the', 'worker'): 1,
#  ('worker', 'who'): 6,
#  ('who', 'had'): 177,
#  ('had', 'cut'): 4,
#  ('cut', 'his'): 6,
#  ('his', 'finger'): 4,
#  ('finger', 'was'): 2,
#  ('was', 'had'): 1,
#  ('been', 'told'): 16,
#  ('told', 'by'): 12,
#  ('by', 'his'): 85,
#  ('his', 'supervisor'): 1,
#  ('supervisor', 'to'): 1,
#  ('to', 'put'): 110,
#  ('put', '<u n k>'): 13,
#  ('on', 'it'): 43,
#  ('it', 'and'): 38,
#  ('and', 'continue'): 15,
#  ('continue', 'with'): 7,
#  ('with', 'his'): 212,
#  ('his', 'work'): 12,
#  ('work', '.'): 83,
#  ('The', 'publishers'): 1,
#  ('publishers', 'of'): 1,
#  ('of', 'The'): 40,
#  ('The', 'Times'): 66,
#  ('Times', 'and'): 5,
#  ('and', 'Michael'): 16,
#  ('Michael', '<u n k>'): 99,
#  (',', 'a'): 2184,
#  ('a', 'juror'): 2,
#  ('juror', ','): 2,
#  (',', 'were'): 153,
#  ('were', 'accused'): 9,
#  ('accused', 'of'): 130,
#  ('the', 'secrets'): 1,
#  ('secrets', 'of'): 2,
#  ('jury', 'room'): 1,
#  ('room', 'in'): 12,
#  ('in', 'articles'): 2,
#  ('articles', 'about'): 3,
#  ('about', 'his'): 62,
#  ('his', 'concerns'): 5,
#  ('concerns', 'over'): 14,
#  ('over', 'a'): 117,
#  ('verdict', '.'): 6,
#  ('<s t a r t>', 'Austrian'): 2,
#  ('Austrian', '<u n k>'): 3,
#  ('who', 'leads'): 5,
#  ('leads', 'the'): 21,
#  ('the', 'overall'): 47,
#  ('overall', 'rankings'): 1,
#  ('rankings', ','): 4,
#  (',', 'came'): 21,
#  ('in', 'only'): 8,
#  ('only', '15th'): 1,
#  ('15th', 'on'): 2,
#  ('on', 'the'): 2732,
#  ('the', 'second'): 336,
#  ('second', 'leg'): 8,
#  ('leg', 'after'): 1,
#  ('after', 'finishing'): 6,
#  ('finishing', 'just'): 1,
#  ('just', 'behind'): 3,
#  ('behind', 'the'): 96,
#  ('the', 'Finn'): 3,
#  ('Finn', 'on'): 1,
#  ('the', 'first'): 990,
#  ('first', 'run'): 4,
#  ('run', '.'): 26,
#  ('The', 'research'): 12,
#  ('research', 'team'): 2,
#  ('team', 'are'): 6,
#  ('are', 'to'): 58,
#  ('to', 'publish'): 12,
#  ('publish', 'their'): 2,
#  ('their', 'findings'): 10,
#  ('findings', 'in'): 6,
#  ('<u n k>', 'Journal'): 4,
#  ('Journal', '.'): 3,
#  ('<u n k>', ':'): 456,
#  ('<u n k>', '('): 881,
#  ('(', 'Real'): 1,
#  ('Real', 'Madrid'): 19,
#  ('Madrid', ')'): 1,
#  (')', ','): 811,
#  (',', 'Jose'): 4,
#  ('Jose', 'Reina'): 1,
#  ('Reina', '('): 1,
#  ('(', 'Liverpool'): 2,
#  ('Liverpool', ')'): 2,
#  (')', '.'): 565,
#  ('<s t a r t>', 'According'): 145,
#  ('According', 'to'): 150,
#  ...}

# %%
# Bi grams
cnt_bi

prob_list_bi = []
tups = []
word_prob_bi = {}

for tup,v in cnt_bi.items():
  tups.append(tup)
  prob_list_bi.append(v/vocab_counts[tup[0]])
  word_prob_bi[tup] = v/vocab_counts[tup[0]]

N_bi = 0
for k,v in cnt_bi.items():
  N_bi += v

di_bi = {'Word_bi': tups, 'Probability' : prob_list_bi}
df_bi = pd.DataFrame(data = di_bi)
df_bi
# Out:
#                            Word_bi  Probability
# 0       (<s t a r t>, <s t a r t>)     1.000000
# 1            (<s t a r t>, Having)     0.000699
# 2                      (Having, a)     0.085106
# 3                      (a, little)     0.005246
# 4            (little, flexibility)     0.002160
# ...                            ...          ...
# 464262                 (than, 325)     0.000395
# 464263                (325, times)     0.166667
# 464264            (and, undergone)     0.000031
# 464265           (undergone, nine)     0.090909
# 464266          (nine, operations)     0.004739
#
# [464267 rows x 2 columns]

# %%
#Tri Grams
N_tri = 0
for k,v in cnt_tri.items():
  N_tri += v

prob_list_tri = []
tups_tri = []
tup_bi_1 = []
word_prob_tri = {}

for tup,v in cnt_tri.items():
  tups_tri.append(tup)
  prob_list_tri.append(v/cnt_bi[(tup[0], tup[1])])
  tup_bi_1.append((tup[0], tup[1]))
  word_prob_tri[tup] = v/cnt_bi[(tup[0], tup[1])]

di = {'Word_tri': tups_tri, 'Probability' : prob_list_tri, 'Word_bi': tup_bi_1}
df_tri = pd.DataFrame(data = di)
df_tri
# Out:
#                                    Word_tri  Probability  \
# 0        (<s t a r t>, <s t a r t>, Having)     0.000699
# 1                  (<s t a r t>, Having, a)     0.069767
# 2                       (Having, a, little)     0.250000
# 3                  (a, little, flexibility)     0.006061
# 4                 (little, flexibility, on)     1.000000
# ...                                     ...          ...
# 1072245                   (325, times, and)     1.000000
# 1072246             (times, and, undergone)     0.047619
# 1072247              (and, undergone, nine)     1.000000
# 1072248       (undergone, nine, operations)     1.000000
# 1072249               (nine, operations, .)     1.000000
#
#                             Word_bi
# 0        (<s t a r t>, <s t a r t>)
# 1             (<s t a r t>, Having)
# 2                       (Having, a)
# 3                       (a, little)
# 4             (little, flexibility)
# ...                             ...
# 1072245                (325, times)
# 1072246                (times, and)
# 1072247            (and, undergone)
# 1072248           (undergone, nine)
# 1072249          (nine, operations)
#
# [1072250 rows x 3 columns]

# %%
log_sum_tri = 0
for i in range(len(prob_list_tri)):
  log_sum_tri += np.log(prob_list_tri[i])*cnt_tri[tups_tri[i]]

ppx_tri_train = np.exp((-1/N_tri)*log_sum_tri)
print("The trigram perplexity on the training set: ", round(ppx_tri_train, 3))
# Out:
# The trigram perplexity on the training set:  8.595

# %%
# Get the dataframe of tri-gram of each word with it's probabilities

# This is for the Test set
# Trying to use laplace smoothing 

#cnt_tri_sub = {}
prob_tri_test = []
tri_word_test = []
alpha = 1
f_test = "" # The path of the file that contains that test tokens. In my case it is of sentences form line by line.

with open(f_test) as file:
  for line in file:
    arr = token_tri(line, word_dict)
    for tri in arr:
      tri_word_test.append(tri)
      if tri in word_prob_tri:
        prob_tri_test.append(word_prob_tri[tri])
      else:
        if (tri[0], tri[1]) in word_prob_bi:
          prob_tri_test.append(alpha/(cnt_bi[(tri[0], tri[1])] + V))
        else:
          prob_tri_test.append(alpha/V)
      
di_tri_test = {'Word_tri_test': tri_word_test, 'Prob_tri_test' : prob_tri_test}
df_tri_test = pd.DataFrame(data = di_tri_test)
df_tri_test
# Out:
#                               Word_tri_test  Prob_tri_test
# 0       (<s t a r t>, <s t a r t>, BAGHDAD)       0.000195
# 1                (<s t a r t>, BAGHDAD, --)       0.166667
# 2                         (BAGHDAD, --, An)       0.000055
# 3                           (--, An, Iraqi)       0.000055
# 4                     (An, Iraqi, military)       0.000055
# ...                                     ...            ...
# 318281              (<u n k>, 's, personal)       0.001203
# 318282              ('s, personal, adviser)       0.000055
# 318283               (personal, adviser, ])       0.000055
# 318284                      (adviser, ], .)       0.000055
# 318285                    (], ., <s t o p>)       0.666667
#
# [318286 rows x 2 columns]

# %%
N_tri_test = len(prob_tri_test)
log_sum_tri_test = 0

for i in range(N_tri_test):
  log_sum_tri_test += np.log(prob_tri_test[i])

ppx_test_tri = np.exp(log_sum_tri_test * (-1/N))
print("The trigram perplexity of the test set: ", ppx_test_tri)
# Out:
# The trigram perplexity of the test set:  3.7994624066758442
